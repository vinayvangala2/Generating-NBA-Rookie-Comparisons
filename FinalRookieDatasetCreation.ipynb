# %%
import pandas as pd

players = pd.read_csv("nba_advanced_stats_2001_2025_players.csv")
averages = pd.read_csv("nba_advanced_stats_2001_2025_league_averages.csv")

cols_to_normalize = ["TS%", "3PAr", "FTr", "ORB%", "DRB%", "TRB%",
                     "AST%", "STL%", "BLK%", "TOV%", "USG%"]

players = players.loc[:, ~players.columns.str.contains("^Unnamed|^Rk$")]
averages = averages.loc[:, ~averages.columns.str.contains("^Unnamed|^Rk$")]

players["Season"] = players["Season"].astype(str)
averages["Season"] = averages["Season"].astype(str)

merged = players.merge(averages[["Season"] + cols_to_normalize],
                       on="Season", how="left", suffixes=("", "_LEAGUE"))

for col in cols_to_normalize:
    league_col = f"{col}_LEAGUE"
    merged[col] = merged[col] / merged[league_col]

merged.drop(columns=[f"{col}_LEAGUE" for col in cols_to_normalize], inplace=True)

merged.to_csv("nba_advanced_stats_normalized_2001_2025.csv", index=False)

print("Normalized columns saved to nba_advanced_stats_normalized_2001_2025.csv")
# Out:
# ✅ Normalized columns saved to nba_advanced_stats_normalized_2001_2025.csv

# %%
df = pd.read_csv("nba_advanced_stats_normalized_2001_2025.csv")

combined_rows = df[df["Team"].str.contains("TM", na=False)].copy()

combined_keys = set(zip(combined_rows["Player"], combined_rows["Season"]))

df_filtered = df[
    df.apply(lambda row: (row["Player"], row["Season"]) not in combined_keys or "TM" in str(row["Team"]), axis=1)
].copy()

df_filtered.to_csv("nba_advanced_stats_normalized_cleaned_multiteam.csv", index=False)

print("Saved file with only combined multi-team rows as nba_advanced_stats_normalized_cleaned_multiteam.csv")
# Out:
# ✅ Saved file with only combined multi-team rows as nba_advanced_stats_normalized_cleaned_multiteam.csv

# %%
advanced = pd.read_csv("nba_advanced_stats_normalized_cleaned_multiteam.csv")
rookies = pd.read_csv("nba_rookie_names_and_seasons.csv")

def clean_player_name(name):
    return name.strip().replace("*", "")

rookies["Player"] = rookies["Player"].astype(str).apply(clean_player_name)
advanced["Player"] = advanced["Player"].astype(str).str.strip()

rookies["Season"] = rookies["Season"].astype(str).str.strip()
advanced["Season"] = advanced["Season"].astype(str).str.strip()

merged = pd.merge(rookies, advanced, on=["Player", "Season"], how="inner")

rookie_keys = set(zip(rookies["Player"], rookies["Season"]))
matched_keys = set(zip(merged["Player"], merged["Season"]))
unmatched_keys = rookie_keys - matched_keys

print("\n Rookies not found in advanced stats:")
for player, season in sorted(unmatched_keys):
    print(f"- {player} ({season})")

merged.to_csv("rookie_advanced_stats_normalized.csv", index=False)
print("\n Saved merged rookie stats to rookie_advanced_stats_normalized.csv")
# Out:
#  Rookies not found in advanced stats:
#
#  Saved merged rookie stats to rookie_advanced_stats_normalized.csv

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import re

rookie_stats = pd.read_csv("rookie_advanced_stats_normalized.csv")
combine = pd.read_csv("draftcombine_cleaned.csv")

def normalize_name(name):
    name = name.lower().strip()
    name = re.sub(r'\b(jr|sr|iii|ii|iv)\b\.?', '', name)
    name = re.sub(r'[^\w\s]', '', name) 
    name = re.sub(r'\s+', ' ', name) 
    return name.strip()

rookie_stats["Player_norm"] = rookie_stats["Player"].apply(normalize_name)
combine["PLAYER_norm"] = combine["PLAYER"].apply(normalize_name)

threshold = 75

match_dict = {}
closest_match_dict = {}

for player, norm_name in zip(combine["PLAYER"], combine["PLAYER_norm"]):
    result = process.extractOne(norm_name, rookie_stats["Player_norm"].tolist(), scorer=fuzz.token_sort_ratio)
    
    if result:
        match_norm, score = result
        closest_player = rookie_stats.loc[rookie_stats["Player_norm"] == match_norm, "Player"].values[0]
        closest_match_dict[player] = (closest_player, score)
        
        if score >= threshold:
            match_dict[player] = closest_player
            print(f"✅ Match: {player} → {closest_player} (score: {score})")
        else:
            match_dict[player] = None
            print(f"❌ No strong match: {player} → Closest: {closest_player} (score: {score})")
    else:
        match_dict[player] = None
        closest_match_dict[player] = ("No match found", 0)
        print(f"❌ No match found: {player}")

combine["Player"] = combine["PLAYER"].map(match_dict)

matched_combine = combine[combine["Player"].notna()].copy()

merged = pd.merge(rookie_stats, matched_combine, on="Player", how="left", suffixes=("", "_combine"))

merged.to_csv("rookie_stats_with_combine_fuzzy.csv", index=False)
print("Saved final merged file to rookie_stats_with_combine_fuzzy.csv")

unmatched = combine[combine["Player"].isna()]
if not unmatched.empty:
    print("\n Combine players that didn't match any rookie stats:")
    for name in unmatched["PLAYER"]:
        closest_name, closest_score = closest_match_dict.get(name, ("No match found", 0))
        print(f"- {name} → Closest: {closest_name} (score: {closest_score})")
# Out:
# ✅ Match: Michael Ajayi → Ajay Mitchell (score: 85)
# ❌ No strong match: Melvin Ajinca → Closest: Melvin Frazier (score: 67)
# ✅ Match: Trey Alexander → Trey Alexander (score: 100)
# ✅ Match: Reece Beekman → Reece Beekman (score: 100)
# ✅ Match: Adem Bona → Adem Bona (score: 100)
# ❌ No strong match: Trevon Brazile → Closest: Tony Bradley (score: 69)
# ✅ Match: Jalen Bridges → Jalen Bridges (score: 100)
# ✅ Match: Matas Buzelis → Matas Buzelis (score: 100)
# ❌ No strong match: Carlton Carrington → Closest: Aaron Harrison (score: 69)
# ✅ Match: Devin Carter → Devin Carter (score: 100)
# ✅ Match: Stephon Castle → Stephon Castle (score: 100)
# ✅ Match: Ulrich Chomche → Ulrich Chomche (score: 100)
# ✅ Match: Cam Christie → Cam Christie (score: 100)
# ✅ Match: Donovan Clingan → Donovan Clingan (score: 100)
# ✅ Match: Isaiah Collier → Isaiah Collier (score: 100)
# ✅ Match: Tristan Da Silva → Tristan Da Silva (score: 100)
# ✅ Match: Pacome Dadiet → Pacome Dadiet (score: 100)
# ✅ Match: N'Faly Dante → N'Faly Dante (score: 100)
# ✅ Match: Robert Dillingham → Rob Dillingham (score: 90)
# ❌ No strong match: Nikola Djurisic → Closest: Nikola JokiÄ‡ (score: 69)
# ✅ Match: Ryan Dunn → Ryan Dunn (score: 100)
# ✅ Match: Zach Edey → Zach Edey (score: 100)
# ✅ Match: Jesse Edwards → Jesse Edwards (score: 100)
# ✅ Match: Justin Edwards → Justin Edwards (score: 100)
# ❌ No strong match: Boogie Ellis → Closest: Reggie Williams (score: 59)
# ✅ Match: Kyle Filipowski → Kyle Filipowski (score: 100)
# ✅ Match: Trentyn Flowers → Trentyn Flowers (score: 100)
# ✅ Match: Enrique Freeman → Enrique Freeman (score: 100)
# ✅ Match: Johnny Furphy → Johnny Furphy (score: 100)
# ✅ Match: Kyshawn George → Kyshawn George (score: 100)
# ❌ No strong match: Tyon Grant-Foster → Closest: Hunter Tyson (score: 64)
# ✅ Match: PJ Hall → PJ Hall (score: 100)
# ❌ No strong match: Coleman Hawkins → Closest: Andre Dawkins (score: 64)
# ✅ Match: Ron Holland II → Ron Holland (score: 100)
# ❌ No strong match: DaRon Holmes II → Closest: Aaron Miles (score: 70)
# ✅ Match: Ariel Hukporti → Ariel Hukporti (score: 100)
# ✅ Match: Oso Ighodaro → Oso Ighodaro (score: 100)
# ✅ Match: Harrison Ingram → Harrison Ingram (score: 100)
# ✅ Match: Bronny James → Bronny James (score: 100)
# ✅ Match: AJ Johnson → AJ Johnson (score: 100)
# ✅ Match: Keshad Johnson → Keshad Johnson (score: 100)
# ✅ Match: David Jones → David Johnson (score: 83)
# ✅ Match: Dillon Jones → Dillon Jones (score: 100)
# ✅ Match: Isaac Jones → Isaac Jones (score: 100)
# ❌ No strong match: Alex Karaban → Closest: Alex Garcia (score: 70)
# ✅ Match: Bobi Klintman → Bobi Klintman (score: 100)
# ✅ Match: Dalton Knecht → Dalton Knecht (score: 100)
# ✅ Match: Tyler Kolek → Tyler Kolek (score: 100)
# ✅ Match: Pelle Larsson → Pelle Larsson (score: 100)
# ✅ Match: Jared McCain → Jared McCain (score: 100)
# ✅ Match: Kevin McCullar Jr. → Kevin McCullar Jr. (score: 100)
# ✅ Match: Yves Missi → Yves Missi (score: 100)
# ✅ Match: Ajay Mitchell → Ajay Mitchell (score: 100)
# ✅ Match: Jonathan Mogbo → Jonathan Mogbo (score: 100)
# ✅ Match: Tristen Newton → Tristen Newton (score: 100)
# ❌ No strong match: Juan Nunez → Closest: Julyan Stone (score: 64)
# ✅ Match: Quinten Post → Quinten Post (score: 100)
# ✅ Match: Antonio Reeves → Antonio Reeves (score: 100)
# ✅ Match: Zaccharie Risacher → Zaccharie Risacher (score: 100)
# ✅ Match: Jaxson Robinson → Justin Robinson (score: 80)
# ✅ Match: Tidjane Salaun → Tidjane SalaÃ¼n (score: 96)
# ❌ No strong match: Payton Sandfort → Closest: Deandre Ayton (score: 71)
# ✅ Match: Alexandre Sarr → Alex Sarr (score: 78)
# ✅ Match: Baylor Scheierman → Baylor Scheierman (score: 100)
# ✅ Match: Terrence Shannon Jr. → Terrence Shannon Jr. (score: 100)
# ✅ Match: Jamal Shead → Jamal Shead (score: 100)
# ✅ Match: Reed Sheppard → Reed Sheppard (score: 100)
# ✅ Match: KJ Simpson → KJ Simpson (score: 100)
# ✅ Match: Tyler Smith → Tyler Smith (score: 100)
# ✅ Match: Cam Spencer → Cam Spencer (score: 100)
# ✅ Match: Nae'Qwan Tomlin → Nae'Qwan Tomlin (score: 100)
# ❌ No strong match: Nikola Topic → Closest: Nikola PekoviÄ‡ (score: 72)
# ✅ Match: JT Toppin → Jacob Toppin (score: 76)
# ✅ Match: Jaylon Tyson → Jaylon Tyson (score: 100)
# ✅ Match: Ja'Kobe Walter → Ja'Kobe Walter (score: 100)
# ✅ Match: Kel'el Ware → Kel'el Ware (score: 100)
# ✅ Match: Jaylen Wells → Jaylen Wells (score: 100)
# ✅ Match: Cody Williams → Cody Williams (score: 100)
# ✅ Match: Amari Bailey → Amari Bailey (score: 100)
# ✅ Match: Emoni Bates → Emoni Bates (score: 100)
# ✅ Match: Anthony Black → Anthony Black (score: 100)
# ✅ Match: Kobe Brown → Kobe Brown (score: 100)
# ✅ Match: Kobe Bufkin → Kobe Bufkin (score: 100)
# ✅ Match: Toumani Camara → Toumani Camara (score: 100)
# ✅ Match: Sidy Cissoko → Sidy Cissoko (score: 100)
# ✅ Match: Jaylen Clark → Jaylen Clark (score: 100)
# ✅ Match: Ricky Council IV → Ricky Council IV (score: 100)
# ✅ Match: Gradey Dick → Gradey Dick (score: 100)
# ✅ Match: Adam Flagler → Adam Flagler (score: 100)
# ✅ Match: Mouhamed Gueye → Mouhamed Gueye (score: 100)
# ✅ Match: Jordan Hawkins → Jordan Hawkins (score: 100)
# ✅ Match: Taylor Hendricks → Taylor Hendricks (score: 100)
# ✅ Match: Jalen Hood-Schifino → Jalen Hood-Schifino (score: 100)
# ✅ Match: Andre Jackson Jr. → Andre Jackson Jr. (score: 100)
# ✅ Match: Trayce Jackson-Davis → Trayce Jackson-Davis (score: 100)
# ✅ Match: GG Jackson → GG Jackson II (score: 100)
# ✅ Match: Jaime Jaquez Jr. → Jaime Jaquez Jr. (score: 100)
# ✅ Match: Keyontae Johnson → Keyontae Johnson (score: 100)
# ✅ Match: Colby Jones → Colby Jones (score: 100)
# ❌ No strong match: Arthur Kaluma → Closest: Darrell Arthur (score: 67)
# ❌ No strong match: Mojave King → Closest: Kevin Love (score: 67)
# ✅ Match: Maxwell Lewis → Maxwell Lewis (score: 100)
# ✅ Match: Chris Livingston → Chris Livingston (score: 100)
# ✅ Match: Seth Lundy → Seth Lundy (score: 100)
# ✅ Match: Mike Miles Jr. → Mike Miller (score: 86)
# ✅ Match: Jordan Miller → Jordan Miller (score: 100)
# ✅ Match: Leonard Miller → Leonard Miller (score: 100)
# ❌ No strong match: Judah Mintz → Closest: Josh Minott (score: 64)
# ✅ Match: Dillon Mitchell → Davion Mitchell (score: 87)
# ❌ No strong match: Omari Moore → Closest: Omar Cook (score: 70)
# ✅ Match: Kris Murray → Kris Murray (score: 100)
# ✅ Match: Julian Phillips → Julian Phillips (score: 100)
# ✅ Match: Jalen Pickett → Jalen Pickett (score: 100)
# ✅ Match: Brandin Podziemski → Brandin Podziemski (score: 100)
# ✅ Match: Olivier-Maxence Prosper → Olivier-Maxence Prosper (score: 100)
# ✅ Match: Rayan Rupert → Rayan Rupert (score: 100)
# ✅ Match: Adama Sanogo → Adama Sanogo (score: 100)
# ✅ Match: Marcus Sasser → Marcus Sasser (score: 100)
# ✅ Match: Ben Sheppard → Ben Sheppard (score: 100)
# ✅ Match: Jalen Slawson → Jalen Slawson (score: 100)
# ✅ Match: Terquavion Smith → Terquavion Smith (score: 100)
# ✅ Match: Julian Strawther → Julian Strawther (score: 100)
# ✅ Match: Amen Thompson → Amen Thompson (score: 100)
# ✅ Match: Ausar Thompson → Ausar Thompson (score: 100)
# ✅ Match: Drew Timme → Drew Timme (score: 100)
# ✅ Match: Oscar Tshiebwe → Oscar Tshiebwe (score: 100)
# ❌ No strong match: Azuolas Tubelis → Closest: Tyrus Thomas (score: 52)
# ✅ Match: Tristan Vukcevic → Tristan Vukcevic (score: 100)
# ✅ Match: Jarace Walker → Jarace Walker (score: 100)
# ✅ Match: Cason Wallace → Cason Wallace (score: 100)
# ✅ Match: Jordan Walsh → Jordan Walsh (score: 100)
# ✅ Match: Dariq Whitehead → Dariq Whitehead (score: 100)
# ✅ Match: Cam Whitmore → Cam Whitmore (score: 100)
# ✅ Match: Jalen Wilson → Jalen Wilson (score: 100)
# ✅ Match: Isaiah Wong → Isaiah Wong (score: 100)
# ✅ Match: Ochai Agbaji → Ochai Agbaji (score: 100)
# ✅ Match: Patrick Baldwin Jr. → Patrick Baldwin Jr. (score: 100)
# ✅ Match: Dominick Barlow → Dominick Barlow (score: 100)
# ✅ Match: MarJon Beauchamp → MarJon Beauchamp (score: 100)
# ❌ No strong match: Hugo Besson → Closest: Keith Benson (score: 61)
# ✅ Match: Malaki Branham → Malaki Branham (score: 100)
# ✅ Match: Christian Braun → Christian Braun (score: 100)
# ✅ Match: Kendall Brown → Kendall Brown (score: 100)
# ✅ Match: John Butler Jr. → John Butler (score: 100)
# ✅ Match: Julian Champagnie → Julian Champagnie (score: 100)
# ✅ Match: Kennedy Chandler → Kennedy Chandler (score: 100)
# ✅ Match: Max Christie → Max Christie (score: 100)
# ❌ No strong match: Kofi Cockburn → Closest: Courtney Sims (score: 54)
# ✅ Match: Dyson Daniels → Dyson Daniels (score: 100)
# ✅ Match: Johnny Davis → Johnny Davis (score: 100)
# ✅ Match: JD Davison → JD Davison (score: 100)
# ✅ Match: Moussa Diabate → Moussa DiabatÃ© (score: 96)
# ✅ Match: Tari Eason → Tari Eason (score: 100)
# ✅ Match: Keon Ellis → Keon Ellis (score: 100)
# ✅ Match: Michael Foster Jr. → Michael Foster Jr. (score: 100)
# ✅ Match: Collin Gillespie → Collin Gillespie (score: 100)
# ✅ Match: Ron Harper Jr. → Ron Harper Jr. (score: 100)
# ✅ Match: Nikola Jovic → Nikola JoviÄ‡ (score: 96)
# ✅ Match: Johnny Juzang → Johnny Juzang (score: 100)
# ✅ Match: Trevor Keels → Trevor Keels (score: 100)
# ✅ Match: Walker Kessler → Walker Kessler (score: 100)
# ✅ Match: Christian Koloko → Christian Koloko (score: 100)
# ✅ Match: Jake LaRavia → Jake LaRavia (score: 100)
# ❌ No strong match: Justin Lewis → Closest: Justin Williams (score: 74)
# ✅ Match: E.J. Liddell → E.J. Liddell (score: 100)
# ✅ Match: Bennedict Mathurin → Bennedict Mathurin (score: 100)
# ❌ No strong match: Matthew Mayer → Closest: Wesley Matthews (score: 64)
# ✅ Match: Bryce McGowens → Bryce McGowens (score: 100)
# ❌ No strong match: Aminu Mohammed → Closest: Mouhamed Gueye (score: 64)
# ❌ No strong match: Iverson Molinar → Closest: Malik Hairston (score: 62)
# ❌ No strong match: Jean Montero → Closest: Luis Montero (score: 67)
# ✅ Match: Wendell Moore → Wendell Moore Jr. (score: 100)
# ✅ Match: Andrew Nembhard → Andrew Nembhard (score: 100)
# ✅ Match: Scotty Pippen Jr. → Scotty Pippen Jr. (score: 100)
# ❌ No strong match: Gabriele Procida → Closest: Ariel Hukporti (score: 60)
# ✅ Match: Orlando Robinson → Orlando Robinson (score: 100)
# ✅ Match: David Roddy → David Roddy (score: 100)
# ✅ Match: Ryan Rollins → Ryan Rollins (score: 100)
# ✅ Match: Dereon Seabron → Dereon Seabron (score: 100)
# ✅ Match: Shaedon Sharpe → Shaedon Sharpe (score: 100)
# ❌ No strong match: Matteo Spagnolo → Closest: Paolo Banchero (score: 62)
# ✅ Match: Dalen Terry → Dalen Terry (score: 100)
# ✅ Match: Jabari Walker → Jabari Walker (score: 100)
# ✅ Match: TyTy Washington Jr. → TyTy Washington Jr. (score: 100)
# ✅ Match: Peyton Watson → Peyton Watson (score: 100)
# ✅ Match: Blake Wesley → Blake Wesley (score: 100)
# ✅ Match: Alondes Williams → Alondes Williams (score: 100)
# ✅ Match: Jalen Williams → Jalen Williams (score: 100)
# ✅ Match: Jaylin Williams → Jaylin Williams (score: 100)
# ✅ Match: Mark Williams → Mark Williams (score: 100)
# ✅ Match: Trevion Williams → Marvin Williams (score: 84)
# ❌ No strong match: Max Abmas → Closest: Mark Madsen (score: 60)
# ✅ Match: Marcus Bagley → Marcus Bagley (score: 100)
# ✅ Match: Scottie Barnes → Scottie Barnes (score: 100)
# ✅ Match: Charles Bassey → Charles Bassey (score: 100)
# ✅ Match: Brandon Boston Jr. → Brandon Boston Jr. (score: 100)
# ✅ Match: James Bouknight → James Bouknight (score: 100)
# ✅ Match: Greg Brown III → Greg Brown III (score: 100)
# ✅ Match: Jared Butler → Jared Butler (score: 100)
# ✅ Match: Justin Champagnie → Justin Champagnie (score: 100)
# ✅ Match: Josh Christopher → Josh Christopher (score: 100)
# ✅ Match: Ayo Dosunmu → Ayo Dosunmu (score: 100)
# ✅ Match: David Duke Jr. → David Duke Jr. (score: 100)
# ✅ Match: Kessler Edwards → Kessler Edwards (score: 100)
# ✅ Match: Luka Garza → Luka Garza (score: 100)
# ✅ Match: RaiQuan Gray → RaiQuan Gray (score: 100)
# ✅ Match: Quentin Grimes → Quentin Grimes (score: 100)
# ✅ Match: Sam Hauser → Sam Hauser (score: 100)
# ✅ Match: Aaron Henry → Aaron Henry (score: 100)
# ✅ Match: Matt Hurt → Matthew Hurt (score: 86)
# ❌ No strong match: Nah'Shon Hyland → Closest: Ron Holland (score: 64)
# ✅ Match: David Johnson → David Johnson (score: 100)
# ✅ Match: Jalen Johnson → Jalen Johnson (score: 100)
# ✅ Match: Keon Johnson → Keon Johnson (score: 100)
# ✅ Match: Carlik Jones → Carlik Jones (score: 100)
# ✅ Match: Herbert Jones → Herbert Jones (score: 100)
# ✅ Match: Kai Jones → Kai Jones (score: 100)
# ✅ Match: Corey Kispert → Corey Kispert (score: 100)
# ✅ Match: AJ Lawson → A.J. Lawson (score: 100)
# ✅ Match: Scottie Lewis → Scottie Lewis (score: 100)
# ✅ Match: Isaiah Livers → Isaiah Livers (score: 100)
# ✅ Match: Makur Maker → Maurice Baker (score: 75)
# ✅ Match: Sandro Mamukelashvili → Sandro Mamukelashvili (score: 100)
# ✅ Match: Tre Mann → Tre Mann (score: 100)
# ✅ Match: Miles McBride → Miles McBride (score: 100)
# ✅ Match: Davion Mitchell → Davion Mitchell (score: 100)
# ✅ Match: Isaiah Mobley → Isaiah Mobley (score: 100)
# ✅ Match: Moses Moody → Moses Moody (score: 100)
# ✅ Match: Trey Murphy III → Trey Murphy III (score: 100)
# ✅ Match: Daishen Nix → Daishen Nix (score: 100)
# ✅ Match: John Petty Jr. → Johan Petro (score: 76)
# ✅ Match: Yves Pons → Yves Pons (score: 100)
# ✅ Match: Jason Preston → Jason Preston (score: 100)
# ✅ Match: Joshua Primo → Joshua Primo (score: 100)
# ❌ No strong match: Roko Prkacin → Closest: Rajon Rondo (score: 61)
# ✅ Match: Neemias Queta → Neemias Queta (score: 100)
# ✅ Match: Austin Reaves → Austin Reaves (score: 100)
# ✅ Match: Jeremiah Robinson-Earl → Jeremiah Robinson-Earl (score: 100)
# ✅ Match: Jericho Sims → Jericho Sims (score: 100)
# ✅ Match: Jaden Springer → Jaden Springer (score: 100)
# ❌ No strong match: DJ Steward → Closest: D.J. Strawberry (score: 61)
# ✅ Match: JT Thor → JT Thor (score: 100)
# ✅ Match: Isaiah Todd → Isaiah Todd (score: 100)
# ✅ Match: Duane Washington Jr. → Duane Washington Jr. (score: 100)
# ✅ Match: Trendon Watford → Trendon Watford (score: 100)
# ✅ Match: Joe Wieskamp → Joe Wieskamp (score: 100)
# ✅ Match: Aaron Wiggins → Aaron Wiggins (score: 100)
# ✅ Match: Ziaire Williams → Ziaire Williams (score: 100)
# ✅ Match: McKinley Wright IV → McKinley Wright IV (score: 100)
# ✅ Match: Moses Wright → Moses Wright (score: 100)
# ❌ No strong match: Marcus Zegarowski → Closest: Marcus Smart (score: 62)
# ✅ Match: Precious Achiuwa → Precious Achiuwa (score: 100)
# ✅ Match: Ty-Shon Alexander → Ty-Shon Alexander (score: 100)
# ✅ Match: Udoka Azubuike → Udoka Azubuike (score: 100)
# ✅ Match: Tyler Bey → Tyler Bey (score: 100)
# ❌ No strong match: Yoeli Childs → Closest: Josh Childress (score: 62)
# ✅ Match: Mamadi Diakite → Mamadi Diakite (score: 100)
# ✅ Match: Devon Dotson → Devon Dotson (score: 100)
# ❌ No strong match: Paul Eboua → Closest: Paul George (score: 67)
# ✅ Match: CJ Elleby → CJ Elleby (score: 100)
# ✅ Match: Trent Forrest → Trent Forrest (score: 100)
# ✅ Match: Josh Green → Josh Green (score: 100)
# ✅ Match: Ashton Hagans → Ashton Hagans (score: 100)
# ✅ Match: Joshua Hall → Josh Hall (score: 90)
# ✅ Match: Jalen Harris → Jalen Harris (score: 100)
# ✅ Match: Markus Howard → Markus Howard (score: 100)
# ✅ Match: Elijah Hughes → Elijah Hughes (score: 100)
# ✅ Match: Isaiah Joe → Isaiah Joe (score: 100)
# ✅ Match: Mason Jones → Mason Jones (score: 100)
# ✅ Match: Nathan Knight → Nathan Knight (score: 100)
# ✅ Match: Theo Maledon → ThÃ©o Maledon (score: 96)
# ✅ Match: Karim Mane → Karim ManÃ© (score: 95)
# ✅ Match: Naji Marshall → Naji Marshall (score: 100)
# ✅ Match: Kenyon Martin Jr. → Kenyon Martin (score: 100)
# ✅ Match: Skylar Mays → Skylar Mays (score: 100)
# ✅ Match: Zeke Nnaji → Zeke Nnaji (score: 100)
# ✅ Match: Jordan Nwora → Jordan Nwora (score: 100)
# ✅ Match: Reggie Perry → Reggie Perry (score: 100)
# ✅ Match: Myles Powell → Myles Powell (score: 100)
# ✅ Match: Immanuel Quickley → Immanuel Quickley (score: 100)
# ✅ Match: Jahmi'us Ramsey → Jahmi'us Ramsey (score: 100)
# ✅ Match: Paul Reed Jr. → Paul Reed (score: 100)
# ✅ Match: Nick Richards → Nick Richards (score: 100)
# ✅ Match: Grant Riller → Grant Riller (score: 100)
# ✅ Match: Jayden Scrubb → Jay Scrubb (score: 87)
# ✅ Match: Jalen Smith → Jalen Smith (score: 100)
# ✅ Match: Cassius Stanley → Cassius Stanley (score: 100)
# ✅ Match: Lamar Stevens → Lamar Stevens (score: 100)
# ✅ Match: Isaiah Stewart → Isaiah Stewart (score: 100)
# ✅ Match: Tyrell Terry → Tyrell Terry (score: 100)
# ✅ Match: Killian Tillie → Killian Tillie (score: 100)
# ✅ Match: Xavier Tillman Sr. → Xavier Tillman Sr. (score: 100)
# ❌ No strong match: Kaleb Wesson → Closest: Jalen Wilson (score: 67)
# ❌ No strong match: Kahlil Whitney → Closest: Okaro White (score: 64)
# ✅ Match: Cassius Winston → Cassius Winston (score: 100)
# ✅ Match: Robert Woodard II → Robert Woodard II (score: 100)
# ✅ Match: Nickeil Alexander-Walker → Nickeil Alexander-Walker (score: 100)
# ✅ Match: Darius Bazley → Darius Bazley (score: 100)
# ✅ Match: Bol Bol → Bol Bol (score: 100)
# ✅ Match: Jordan Bone → Jordan Bone (score: 100)
# ✅ Match: Brian Bowen II → Brian Bowen (score: 100)
# ✅ Match: Ky Bowman → Ky Bowman (score: 100)
# ✅ Match: Ignas Brazdeikis → Ignas Brazdeikis (score: 100)
# ✅ Match: O'Shae Brissett → Oshae Brissett (score: 100)
# ✅ Match: Moses Brown → Moses Brown (score: 100)
# ✅ Match: Brandon Clarke → Brandon Clarke (score: 100)
# ✅ Match: Nicolas Claxton → Nic Claxton (score: 85)
# ✅ Match: Tyler Cook → Tyler Cook (score: 100)
# ✅ Match: Jarrett Culver → Jarrett Culver (score: 100)
# ✅ Match: Terence Davis → Terence Davis (score: 100)
# ✅ Match: Luguentz Dort → Luguentz Dort (score: 100)
# ✅ Match: Carsen Edwards → Carsen Edwards (score: 100)
# ✅ Match: Tacko Fall → Tacko Fall (score: 100)
# ✅ Match: Bruno Fernando → Bruno Fernando (score: 100)
# ✅ Match: Daniel Gafford → Daniel Gafford (score: 100)
# ✅ Match: Kyle Guy → Kyle Guy (score: 100)
# ✅ Match: Jaylen Hands → Jaylen Adams (score: 83)
# ✅ Match: Jared Harper → Jared Harper (score: 100)
# ✅ Match: Jaxson Hayes → Jaxson Hayes (score: 100)
# ✅ Match: Dewan Hernandez → Dewan Hernandez (score: 100)
# ✅ Match: Tyler Herro → Tyler Herro (score: 100)
# ✅ Match: Jalen Hoard → Jaylen Hoard (score: 96)
# ✅ Match: Talen Horton-Tucker → Talen Horton-Tucker (score: 100)
# ✅ Match: DaQuan Jeffries → DaQuan Jeffries (score: 100)
# ✅ Match: Ty Jerome → Ty Jerome (score: 100)
# ✅ Match: Cameron Johnson → Cameron Johnson (score: 100)
# ✅ Match: Keldon Johnson → Keldon Johnson (score: 100)
# ✅ Match: Mfiondu Kabengele → Mfiondu Kabengele (score: 100)
# ✅ Match: Louis King → Louis King (score: 100)
# ❌ No strong match: Dedric Lawson → Closest: Cedric Jackson (score: 74)
# ✅ Match: Jalen Lecque → Jalen Lecque (score: 100)
# ✅ Match: Nassir Little → Nassir Little (score: 100)
# ✅ Match: Terance Mann → Terance Mann (score: 100)
# ✅ Match: Cody Martin → Cody Martin (score: 100)
# ❌ No strong match: Charles Matthews → Closest: Matthew Hurt (score: 71)
# ✅ Match: Jalen McDaniels → Jalen McDaniels (score: 100)
# ✅ Match: Zach Norvell Jr. → Zach Norvell (score: 100)
# ✅ Match: Jaylen Nowell → Jaylen Nowell (score: 100)
# ✅ Match: KZ Okpala → KZ Okpala (score: 100)
# ✅ Match: Miye Oni → Miye Oni (score: 100)
# ✅ Match: Eric Paschall → Eric Paschall (score: 100)
# ✅ Match: Shamorie Ponds → Shamorie Ponds (score: 100)
# ✅ Match: Jordan Poole → Jordan Poole (score: 100)
# ✅ Match: Kevin Porter Jr. → Kevin Porter Jr. (score: 100)
# ✅ Match: Jontay Porter → Jontay Porter (score: 100)
# ✅ Match: Cameron Reddish → Cam Reddish (score: 85)
# ✅ Match: Naz Reid → Naz Reid (score: 100)
# ✅ Match: Isaiah Roby → Isaiah Roby (score: 100)
# ❌ No strong match: Luka Samanic → Closest: Santi Aldama (score: 58)
# ✅ Match: Admiral Schofield → Admiral Schofield (score: 100)
# ✅ Match: Marial Shayok → Marial Shayok (score: 100)
# ❌ No strong match: Simisola Shittu → Closest: Joshua Primo (score: 52)
# ✅ Match: P.J. Washington → P.J. Washington (score: 100)
# ✅ Match: Tremont Waters → Tremont Waters (score: 100)
# ✅ Match: Quinndary Weatherspoon → Quinndary Weatherspoon (score: 100)
# ✅ Match: Coby White → Coby White (score: 100)
# ❌ No strong match: Kris Wilkes → Closest: Darius Miles (score: 70)
# ✅ Match: Grant Williams → Grant Williams (score: 100)
# ✅ Match: Dylan Windler → Dylan Windler (score: 100)
# ✅ Match: Rawle Alkins → Rawle Alkins (score: 100)
# ✅ Match: Grayson Allen → Grayson Allen (score: 100)
# ✅ Match: Kostas Antetokounmpo → Kostas Antetokounmpo (score: 100)
# ✅ Match: Mohamed Bamba → Mo Bamba (score: 76)
# ✅ Match: Jaylen Barford → Jaylen Brown (score: 77)
# ✅ Match: Keita Bates-Diop → Keita Bates-Diop (score: 100)
# ❌ No strong match: Tyus Battle → Closest: Jamison Battle (score: 64)
# ✅ Match: Brian Bowen → Brian Bowen (score: 100)
# ✅ Match: Miles Bridges → Miles Bridges (score: 100)
# ✅ Match: Bruce Brown → Bruce Brown (score: 100)
# ✅ Match: Troy Brown → Troy Brown Jr. (score: 100)
# ✅ Match: Jalen Brunson → Jalen Brunson (score: 100)
# ✅ Match: Tony Carr → Tony Parker (score: 80)
# ✅ Match: Jevon Carter → Jevon Carter (score: 100)
# ✅ Match: Wendell Carter → Wendell Carter Jr. (score: 100)
# ✅ Match: Hamidou Diallo → Hamidou Diallo (score: 100)
# ✅ Match: Donte DiVincenzo → Donte DiVincenzo (score: 100)
# ✅ Match: Trevon Duval → Trevon Duval (score: 100)
# ✅ Match: Jacob Evans → Jacob Evans (score: 100)
# ❌ No strong match: Keenan Evans → Closest: Reggie Evans (score: 67)
# ✅ Match: Melvin Frazier → Melvin Frazier (score: 100)
# ✅ Match: Shai Gilgeous-Alexander → Shai Gilgeous-Alexander (score: 100)
# ✅ Match: Devonte Graham → Devonte' Graham (score: 100)
# ❌ No strong match: Isaac Haas → Closest: Isaac Bonga (score: 67)
# ✅ Match: Devon Hall → Devon Hall (score: 100)
# ✅ Match: Kevin Hervey → Kevin Hervey (score: 100)
# ✅ Match: Aaron Holiday → Aaron Holiday (score: 100)
# ✅ Match: Kevin Huerter → Kevin Huerter (score: 100)
# ✅ Match: Jaren Jackson → Jaren Jackson Jr. (score: 100)
# ✅ Match: Justin Jackson → Justin Jackson (score: 100)
# ✅ Match: Alize Johnson → Alize Johnson (score: 100)
# ✅ Match: George King → George King (score: 100)
# ✅ Match: Kevin Knox → Kevin Knox (score: 100)
# ❌ No strong match: Sagaba Konate → Closest: Isaac Fontaine (score: 59)
# ✅ Match: Caleb Martin → Caleb Martin (score: 100)
# ✅ Match: Yante Maten → Yante Maten (score: 100)
# ✅ Match: Brandon McCoy → Brandon Roy (score: 83)
# ✅ Match: DeAnthony Melton → De'Anthony Melton (score: 100)
# ✅ Match: Chimezie Metu → Chimezie Metu (score: 100)
# ✅ Match: Shake Milton → Shake Milton (score: 100)
# ✅ Match: Sviatoslav Mykhailiuk → Svi Mykhailiuk (score: 80)
# ✅ Match: Malik Newman → Malik Newman (score: 100)
# ✅ Match: Josh Okogie → Josh Okogie (score: 100)
# ✅ Match: Theo Pinson → Theo Pinson (score: 100)
# ✅ Match: Michael Porter → Michael Porter Jr. (score: 100)
# ❌ No strong match: Billy Preston → Closest: Billy Garrett (score: 69)
# ✅ Match: Jerome Robinson → Jerome Robinson (score: 100)
# ✅ Match: Collin Sexton → Collin Sexton (score: 100)
# ✅ Match: Landry Shamet → Landry Shamet (score: 100)
# ✅ Match: Anfernee Simons → Anfernee Simons (score: 100)
# ✅ Match: Zhaire Smith → Zhaire Smith (score: 100)
# ✅ Match: Ray Spalding → Ray Spalding (score: 100)
# ✅ Match: Omari Spellman → Omari Spellman (score: 100)
# ✅ Match: Khyri Thomas → Khyri Thomas (score: 100)
# ✅ Match: Gary Trent → Gary Trent Jr. (score: 100)
# ✅ Match: Allonzo Trier → Allonzo Trier (score: 100)
# ✅ Match: Moritz Wagner → Moritz Wagner (score: 100)
# ✅ Match: Lonnie Walker → Lonnie Walker IV (score: 100)
# ✅ Match: PJ Washington → P.J. Washington (score: 100)
# ❌ No strong match: Austin Wiley → Closest: Willie Cauley-Stein (score: 73)
# ✅ Match: Kenrich Williams → Kenrich Williams (score: 100)
# ✅ Match: Trae Young → Trae Young (score: 100)
# ❌ No strong match: Edrice Adebayo → Closest: Bam Adebayo (score: 64)
# ✅ Match: Jarrett Allen → Jarrett Allen (score: 100)
# ✅ Match: Kadeem Allen → Kadeem Allen (score: 100)
# ✅ Match: Ike Anigbogu → Ike Anigbogu (score: 100)
# ✅ Match: OG Anunoby → OG Anunoby (score: 100)
# ✅ Match: Jamel Artis → Jamel Artis (score: 100)
# ✅ Match: Dwayne Bacon → Dwayne Bacon (score: 100)
# ❌ No strong match: V.J. Beachem → Closest: MarJon Beauchamp (score: 62)
# ✅ Match: Jordan Bell → Jordan Bell (score: 100)
# ✅ Match: Jaron Blossomgame → Jaron Blossomgame (score: 100)
# ✅ Match: Chris Boucher → Chris Boucher (score: 100)
# ✅ Match: Tony Bradley → Tony Bradley (score: 100)
# ✅ Match: Isaiah Briscoe → Isaiah Briscoe (score: 100)
# ✅ Match: Dillon Brooks → Dillon Brooks (score: 100)
# ✅ Match: Thomas Bryant → Thomas Bryant (score: 100)
# ✅ Match: John Collins → John Collins (score: 100)
# ✅ Match: Zach Collins → Zach Collins (score: 100)
# ✅ Match: Tyler Dorsey → Tyler Dorsey (score: 100)
# ✅ Match: Damyean Dotson → Damyean Dotson (score: 100)
# ✅ Match: PJ Dozier → PJ Dozier (score: 100)
# ✅ Match: Jawun Evans → Jawun Evans (score: 100)
# ✅ Match: Terrance Ferguson → Terrance Ferguson (score: 100)
# ✅ Match: De'Aaron Fox → De'Aaron Fox (score: 100)
# ✅ Match: Harry Giles → Harry Giles (score: 100)
# ✅ Match: Josh Hart → Josh Hart (score: 100)
# ✅ Match: Nigel Hayes → Nigel Hayes (score: 100)
# ✅ Match: Isaiah Hicks → Isaiah Hicks (score: 100)
# ✅ Match: Wesley Iwundu → Wes Iwundu (score: 87)
# ✅ Match: Justin Jackson (UMD) → Justin Jackson (score: 88)
# ✅ Match: Justin Jackson (UNC) → Justin Jackson (score: 88)
# ✅ Match: Frank Jackson → Frank Jackson (score: 100)
# ❌ No strong match: Peter Jok → Closest: Johan Petro (score: 70)
# ✅ Match: Luke Kennard → Luke Kennard (score: 100)
# ✅ Match: Kyle Kuzma → Kyle Kuzma (score: 100)
# ✅ Match: TJ Leaf → T.J. Leaf (score: 100)
# ✅ Match: Tyler Lydon → Tyler Lydon (score: 100)
# ✅ Match: Frank Mason III → Frank Mason III (score: 100)
# ❌ No strong match: Kennedy Meeks → Closest: D.J. Kennedy (score: 61)
# ✅ Match: Donovan Mitchell → Donovan Mitchell (score: 100)
# ✅ Match: Monte Morris → Monte Morris (score: 100)
# ✅ Match: Johnathan Motley → Johnathan Motley (score: 100)
# ✅ Match: Svi Mykhailiuk → Svi Mykhailiuk (score: 100)
# ✅ Match: Semi Ojeleye → Semi Ojeleye (score: 100)
# ✅ Match: Cameron Oliver → Cameron Oliver (score: 100)
# ✅ Match: Justin Patton → Justin Patton (score: 100)
# ✅ Match: Alec Peters → Alec Peters (score: 100)
# ✅ Match: Ivan Rabb → Ivan Rabb (score: 100)
# ✅ Match: Davon Reed → Davon Reed (score: 100)
# ✅ Match: Devin Robinson → Devin Robinson (score: 100)
# ✅ Match: Kobi Simmons → Kobi Simmons (score: 100)
# ✅ Match: Edmond Sumner → Edmond Sumner (score: 100)
# ✅ Match: Caleb Swanigan → Caleb Swanigan (score: 100)
# ✅ Match: Sindarius Thornwell → Sindarius Thornwell (score: 100)
# ❌ No strong match: Melo Trimble → Closest: Allonzo Trier (score: 56)
# ✅ Match: Derrick Walton Jr. → Derrick Walton (score: 100)
# ✅ Match: Thomas Welsh → Thomas Welsh (score: 100)
# ✅ Match: Derrick White → Derrick White (score: 100)
# ✅ Match: Nigel Williams-Goss → Nigel Williams-Goss (score: 100)
# ✅ Match: D.J. Wilson → D.J. Wilson (score: 100)
# ✅ Match: Omer Yurtseven → Omer Yurtseven (score: 100)
# ✅ Match: Ron Baker → Ron Baker (score: 100)
# ✅ Match: Wade Baldwin IV → Wade Baldwin (score: 100)
# ✅ Match: Cat Barber → Cat Barber (score: 100)
# ✅ Match: Malik Beasley → Malik Beasley (score: 100)
# ✅ Match: DeAndre Bembry → DeAndre' Bembry (score: 100)
# ✅ Match: Ben Bentil → Ben Bentil (score: 100)
# ✅ Match: Joel Bolomboy → Joel Bolomboy (score: 100)
# ✅ Match: Malcolm Brogdon → Malcolm Brogdon (score: 100)
# ✅ Match: Jaylen Brown → Jaylen Brown (score: 100)
# ✅ Match: Marquese Chriss → Marquese Chriss (score: 100)
# ❌ No strong match: Elgin Cook → Closest: Quinn Cook (score: 70)
# ❌ No strong match: Isaiah Cousins → Closest: Isaiah Collier (score: 71)
# ✅ Match: Deyonta Davis → Deyonta Davis (score: 100)
# ✅ Match: Cheick Diallo → Cheick Diallo (score: 100)
# ✅ Match: Kris Dunn → Kris Dunn (score: 100)
# ✅ Match: Henry Ellenson → Henry Ellenson (score: 100)
# ❌ No strong match: Perry Ellis → Closest: Perry Jones (score: 73)
# ✅ Match: Kay Felder → Kay Felder (score: 100)
# ✅ Match: Dorian Finney-Smith → Dorian Finney-Smith (score: 100)
# ✅ Match: Michael Gbinije → Michael Gbinije (score: 100)
# ✅ Match: Daniel Hamilton → Daniel Hamilton (score: 100)
# ✅ Match: Buddy Hield → Buddy Hield (score: 100)
# ✅ Match: Demetrius Jackson → Demetrius Jackson (score: 100)
# ✅ Match: Brice Johnson → Brice Johnson (score: 100)
# ✅ Match: Damian Jones → Damian Jones (score: 100)
# ✅ Match: Skal Labissiere → Skal LabissiÃ¨re (score: 97)
# ✅ Match: Jake Layman → Jake Layman (score: 100)
# ✅ Match: Marcus Lee → Marcus Bagley (score: 78)
# ✅ Match: Caris LeVert → Caris LeVert (score: 100)
# ✅ Match: Thon Maker → Thon Maker (score: 100)
# ✅ Match: Patrick McCaw → Patrick McCaw (score: 100)
# ✅ Match: Georges Niang → Georges Niang (score: 100)
# ✅ Match: Chinanu Onuaku → Chinanu Onuaku (score: 100)
# ✅ Match: Marcus Paige → Marcus Paige (score: 100)
# ✅ Match: Gary Payton II → Gary Payton II (score: 100)
# ✅ Match: Jakob Poeltl → Jakob Poeltl (score: 100)
# ✅ Match: Taurean Prince → Taurean Prince (score: 100)
# ✅ Match: Zhou Qi → Zhou Qi (score: 100)
# ✅ Match: Malachi Richardson → Malachi Richardson (score: 100)
# ✅ Match: Wayne Selden → Wayne Selden (score: 100)
# ✅ Match: Pascal Siakam → Pascal Siakam (score: 100)
# ✅ Match: Diamond Stone → Diamond Stone (score: 100)
# ✅ Match: Tyler Ulis → Tyler Ulis (score: 100)
# ✅ Match: Jarrod Uthoff → Jarrod Uthoff (score: 100)
# ✅ Match: Denzel Valentine → Denzel Valentine (score: 100)
# ✅ Match: Isaiah Whitehead → Isaiah Whitehead (score: 100)
# ✅ Match: Troy Williams → Troy Williams (score: 100)
# ✅ Match: Kyle Wiltjer → Kyle Wiltjer (score: 100)
# ✅ Match: Stephen Zimmerman → Stephen Zimmerman (score: 100)
# ✅ Match: Cliff Alexander → Cliff Alexander (score: 100)
# ✅ Match: Justin Anderson → Justin Anderson (score: 100)
# ✅ Match: Brandon Ashley → Brandon Bass (score: 77)
# ❌ No strong match: Ryan Boatright → Closest: Matt Ryan (score: 70)
# ✅ Match: Devin Booker → Devin Booker (score: 100)
# ✅ Match: Anthony Brown → Anthony Brown (score: 100)
# ✅ Match: Willie Cauley-Stein → Willie Cauley-Stein (score: 100)
# ✅ Match: Rakeem Christmas → Rakeem Christmas (score: 100)
# ✅ Match: Pat Connaughton → Pat Connaughton (score: 100)
# ✅ Match: Quinn Cook → Quinn Cook (score: 100)
# ✅ Match: Branden Dawson → Branden Dawson (score: 100)
# ✅ Match: Sam Dekker → Sam Dekker (score: 100)
# ✅ Match: Michael Frazier II → Michael Frazier (score: 100)
# ✅ Match: Treveon Graham → Treveon Graham (score: 100)
# ✅ Match: Jerian Grant → Jerian Grant (score: 100)
# ❌ No strong match: Olivier Hanlan → Closest: Dean Oliver (score: 72)
# ✅ Match: Montrezl Harrell → Montrezl Harrell (score: 100)
# ✅ Match: Aaron Harrison → Aaron Harrison (score: 100)
# ✅ Match: Andrew Harrison → Andrew Harrison (score: 100)
# ✅ Match: Tyler Harvey → Tyler Bey (score: 76)
# ❌ No strong match: Corey Hawkins → Closest: Cory Higgins (score: 72)
# ✅ Match: Rondae Hollis-Jefferson → Rondae Hollis-Jefferson (score: 100)
# ❌ No strong match: Jonathan Holmes → Closest: Nathan Mensah (score: 71)
# ✅ Match: Richaun Holmes → Richaun Holmes (score: 100)
# ✅ Match: R.J. Hunter → R.J. Hunter (score: 100)
# ✅ Match: Vince Hunter → Vince Hunter (score: 100)
# ✅ Match: Dakari Johnson → Dakari Johnson (score: 100)
# ✅ Match: Stanley Johnson → Stanley Johnson (score: 100)
# ✅ Match: Tyus Jones → Tyus Jones (score: 100)
# ✅ Match: Frank Kaminsky → Frank Kaminsky (score: 100)
# ✅ Match: Kevon Looney → Kevon Looney (score: 100)
# ✅ Match: Trey Lyles → Trey Lyles (score: 100)
# ✅ Match: Jarell Martin → Jarell Martin (score: 100)
# ✅ Match: TJ McConnell → T.J. McConnell (score: 100)
# ✅ Match: Chris McCullough → Chris McCullough (score: 100)
# ✅ Match: Jordan Mickey → Jordan Mickey (score: 100)
# ✅ Match: Larry Nance → Larry Nance Jr. (score: 100)
# ✅ Match: Kelly Oubre → Kelly Oubre Jr. (score: 100)
# ✅ Match: Cameron Payne → Cameron Payne (score: 100)
# ❌ No strong match: Terran Petteway → Closest: Terry Taylor (score: 59)
# ✅ Match: Bobby Portis → Bobby Portis (score: 100)
# ✅ Match: Norman Powell → Norman Powell (score: 100)
# ❌ No strong match: Michael Qualls → Closest: Michael Redd (score: 62)
# ✅ Match: Chasson Randle → Chasson Randle (score: 100)
# ✅ Match: Terry Rozier → Terry Rozier (score: 100)
# ✅ Match: D?Angelo Russell → D'Angelo Russell (score: 100)
# ✅ Match: Keifer Sykes → Keifer Sykes (score: 100)
# ✅ Match: Marcus Thornton → Marcus Thornton (score: 100)
# ❌ No strong match: J.P. Tokoto → Closest: Elie Okobo (score: 53)
# ✅ Match: Myles Turner → Myles Turner (score: 100)
# ❌ No strong match: Robert Upshaw → Closest: Robert Swift (score: 72)
# ✅ Match: Rashad Vaughn → Rashad Vaughn (score: 100)
# ✅ Match: Chris Walker → Henry Walker (score: 75)
# ❌ No strong match: Dez Wells → Closest: Jaylen Wells (score: 67)
# ✅ Match: Alan Williams → Alan Williams (score: 100)
# ✅ Match: Justise Winslow → Justise Winslow (score: 100)
# ✅ Match: Christian Wood → Christian Wood (score: 100)
# ✅ Match: Delon Wright → Delon Wright (score: 100)
# ✅ Match: Jordan Adams → Jordan Adams (score: 100)
# ✅ Match: Kyle Anderson → Kyle Anderson (score: 100)
# ✅ Match: Thanasis Antetokounmpo → Thanasis Antetokounmpo (score: 100)
# ❌ No strong match: Jordan Bachynski → Closest: Jordan Hill (score: 67)
# ✅ Match: Cameron Bairstow → Cameron Bairstow (score: 100)
# ✅ Match: Khem Birch → Khem Birch (score: 100)
# ✅ Match: Alec Brown → Andre Brown (score: 76)
# ✅ Match: Jabari Brown → Jabari Brown (score: 100)
# ✅ Match: Markel Brown → Markel Brown (score: 100)
# ✅ Match: Deonte Burton → Deonte Burton (score: 100)
# ✅ Match: Semaj Christon → Semaj Christon (score: 100)
# ✅ Match: Jordan Clarkson → Jordan Clarkson (score: 100)
# ✅ Match: Aaron Craft → Aaron Gray (score: 76)
# ❌ No strong match: DeAndre Daniels → Closest: Erik Daniels (score: 74)
# ✅ Match: Spencer Dinwiddie → Spencer Dinwiddie (score: 100)
# ✅ Match: Cleanthony Early → Cleanthony Early (score: 100)
# ✅ Match: Melvin Ejim → Melvin Ely (score: 76)
# ✅ Match: Tyler Ennis → Tyler Ennis (score: 100)
# ✅ Match: Dante Exum → Dante Exum (score: 100)
# ❌ No strong match: C.J. Fair → Closest: C.J. Miles (score: 53)
# ✅ Match: Aaron Gordon → Aaron Gordon (score: 100)
# ✅ Match: Jerami Grant → Jerami Grant (score: 100)
# ✅ Match: P.J. Hairston → P.J. Hairston (score: 100)
# ✅ Match: Gary Harris → Gary Harris (score: 100)
# ✅ Match: Joe Harris → Joe Harris (score: 100)
# ✅ Match: Rodney Hood → Rodney Hood (score: 100)
# ✅ Match: Cory Jefferson → Cory Jefferson (score: 100)
# ✅ Match: Nick Johnson → Nick Johnson (score: 100)
# ✅ Match: Sean Kilpatrick → Sean Kilpatrick (score: 100)
# ✅ Match: Alex Kirk → Alex Kirk (score: 100)
# ✅ Match: Zach LaVine → Zach LaVine (score: 100)
# ✅ Match: Devyn Marble → Devyn Marble (score: 100)
# ✅ Match: James McAdoo → James Michael McAdoo (score: 75)
# ✅ Match: K.J. McDaniels → K.J. McDaniels (score: 100)
# ✅ Match: Doug McDermott → Doug McDermott (score: 100)
# ✅ Match: Jordan McRae → Jordan McRae (score: 100)
# ✅ Match: Shabazz Napier → Shabazz Napier (score: 100)
# ✅ Match: Johnny O?Bryant III → Johnny O'Bryant (score: 100)
# ✅ Match: Lamar Patterson → Lamar Patterson (score: 100)
# ✅ Match: Adreian Payne → Adreian Payne (score: 100)
# ✅ Match: Elfrid Payton → Elfrid Payton (score: 100)
# ✅ Match: Dwight Powell → Dwight Powell (score: 100)
# ✅ Match: Julius Randle → Julius Randle (score: 100)
# ✅ Match: Glenn Robinson III → Glenn Robinson III (score: 100)
# ✅ Match: LaQuinton Ross → Quinton Ross (score: 92)
# ✅ Match: Marcus Smart → Marcus Smart (score: 100)
# ✅ Match: Russ Smith → Russ Smith (score: 100)
# ✅ Match: Nik Stauskas → Nik Stauskas (score: 100)
# ✅ Match: Jarnell Stokes → Jarnell Stokes (score: 100)
# ✅ Match: Xavier Thames → Xavier Rathan-Mayes (score: 84)
# ✅ Match: Noah Vonleh → Noah Vonleh (score: 100)
# ✅ Match: T.J. Warren → T.J. Warren (score: 100)
# ✅ Match: C.J. Wilcox → C.J. Wilcox (score: 100)
# ✅ Match: Kendall Williams → Elliot Williams (score: 77)
# ✅ Match: James Young → James Young (score: 100)
# ❌ No strong match: Patric Young → Closest: Nick Young (score: 73)
# ✅ Match: Steven Adams → Steven Adams (score: 100)
# ✅ Match: Vander Blue → Vander Blue (score: 100)
# ✅ Match: Lorenzo Brown → Lorenzo Brown (score: 100)
# ✅ Match: Reggie Bullock → Reggie Bullock (score: 100)
# ✅ Match: Trey Burke → Trey Burke (score: 100)
# ✅ Match: Kentavious Caldwell-Pope → Kentavious Caldwell-Pope (score: 100)
# ✅ Match: Isaiah Canaan → Isaiah Canaan (score: 100)
# ❌ No strong match: Jackie Carmichael → Closest: Michael Redd (score: 62)
# ✅ Match: Michael Carter-Williams → Michael Carter-Williams (score: 100)
# ❌ No strong match: Will Clyburn → Closest: Will Barton (score: 70)
# ✅ Match: Robert Covington → Robert Covington (score: 100)
# ✅ Match: Allen Crabbe → Allen Crabbe (score: 100)
# ✅ Match: Seth Curry → Seth Curry (score: 100)
# ✅ Match: Brandon Davies → Brandon Davies (score: 100)
# ✅ Match: Dewayne Dedmon → Dewayne Dedmon (score: 100)
# ✅ Match: Gorgui Dieng → Gorgui Dieng (score: 100)
# ✅ Match: James Ennis → James Ennis III (score: 100)
# ✅ Match: Carrick Felix → Carrick Felix (score: 100)
# ✅ Match: Jamaal Franklin → Jamaal Franklin (score: 100)
# ✅ Match: Rudy Gobert → Rudy Gobert (score: 100)
# ✅ Match: Archie Goodwin → Archie Goodwin (score: 100)
# ✅ Match: Erick Green → Erick Green (score: 100)
# ✅ Match: Tim Hardaway Jr. → Tim Hardaway Jr. (score: 100)
# ✅ Match: Solomon Hill → Solomon Hill (score: 100)
# ❌ No strong match: Richard Howell → Closest: Chris Richard (score: 67)
# ❌ No strong match: Colton Iverson → Closest: Jason Collier (score: 67)
# ✅ Match: Pierre Jackson → Pierre Jackson (score: 100)
# ✅ Match: Grant Jerrett → Grant Jerrett (score: 100)
# ❌ No strong match: Myck Kabongo → Closest: Alfonzo McKinnie (score: 57)
# ✅ Match: Kenny Kadji → D.J. Kennedy (score: 76)
# ✅ Match: Ryan Kelly → Ryan Kelly (score: 100)
# ✅ Match: Shane Larkin → Shane Larkin (score: 100)
# ✅ Match: Ricky Ledo → Ricky Ledo (score: 100)
# ❌ No strong match: CJ Leslie → Closest: C.J. Miles (score: 71)
# ✅ Match: Trevor Mbakwe → Trevor Booker (score: 77)
# ✅ Match: Ray McCallum → Ray McCallum (score: 100)
# ✅ Match: CJ McCollum → CJ McCollum (score: 100)
# ✅ Match: Ben McLemore → Ben McLemore (score: 100)
# ✅ Match: Tony Mitchell → Tony Mitchell (score: 100)
# ✅ Match: Shabazz Muhammad → Shabazz Muhammad (score: 100)
# ✅ Match: Erik Murphy → Erik Murphy (score: 100)
# ✅ Match: Mike Muscala → Mike Muscala (score: 100)
# ✅ Match: Nerlens Noel → Nerlens Noel (score: 100)
# ✅ Match: Victor Oladipo → Victor Oladipo (score: 100)
# ✅ Match: Kelly Olynyk → Kelly Olynyk (score: 100)
# ✅ Match: Brandon Paul → Brandon Paul (score: 100)
# ✅ Match: Norvel Pelle → Norvel Pelle (score: 100)
# ✅ Match: Mason Plumlee → Mason Plumlee (score: 100)
# ✅ Match: Otto Porter → Otto Porter Jr. (score: 100)
# ✅ Match: Phil Pressey → Phil Pressey (score: 100)
# ✅ Match: Glen Rice → Glen Rice Jr. (score: 100)
# ✅ Match: Andre Roberson → Andre Roberson (score: 100)
# ✅ Match: Dennis Schroder → Dennis SchrÃ¶der (score: 97)
# ✅ Match: Peyton Siva → Peyton Siva (score: 100)
# ✅ Match: Tony Snell → Tony Snell (score: 100)
# ✅ Match: James Southerland → James Southerland (score: 100)
# ✅ Match: Adonis Thomas → Adonis Thomas (score: 100)
# ✅ Match: Deshaun Thomas → Etan Thomas (score: 80)
# ✅ Match: Jeff Withey → Jeff Withey (score: 100)
# ✅ Match: Nate Wolters → Nate Wolters (score: 100)
# ✅ Match: BJ Young → Joe Young (score: 82)
# ✅ Match: Cody Zeller → Cody Zeller (score: 100)
# ✅ Match: Quincy Acy → Quincy Acy (score: 100)
# ✅ Match: Harrison Barnes → Harrison Barnes (score: 100)
# ✅ Match: Will Barton → Will Barton (score: 100)
# ✅ Match: Bradley Beal → Bradley Beal (score: 100)
# ✅ Match: J'Covan Brown → Jaylen Brown (score: 75)
# ✅ Match: William Buford → William Howard (score: 79)
# ✅ Match: Jae Crowder → Jae Crowder (score: 100)
# ✅ Match: Jared Cunningham → Jared Cunningham (score: 100)
# ✅ Match: Anthony Davis → Anthony Davis (score: 100)
# ❌ No strong match: Marcus Denmon → Closest: Marcus Derrickson (score: 73)
# ✅ Match: Andre Drummond → Andre Drummond (score: 100)
# ✅ Match: Kim English → Kim English (score: 100)
# ✅ Match: Festus Ezeli → Festus Ezeli (score: 100)
# ✅ Match: Drew Gordon → Drew Gordon (score: 100)
# ✅ Match: Draymond Green → Draymond Green (score: 100)
# ✅ Match: JaMychal Green → JaMychal Green (score: 100)
# ✅ Match: Maurice Harkless → Maurice Harkless (score: 100)
# ✅ Match: John Henson → John Henson (score: 100)
# ❌ No strong match: Tu Holloway → Closest: Jrue Holiday (score: 61)
# ✅ Match: Robbie Hummel → Robbie Hummel (score: 100)
# ✅ Match: Bernard James → Bernard James (score: 100)
# ✅ Match: John Jenkins → John Jenkins (score: 100)
# ✅ Match: Darius Johnson-Odom → Darius Johnson-Odom (score: 100)
# ✅ Match: Orlando Johnson → Orlando Johnson (score: 100)
# ✅ Match: Kevin Jones → Kevin Jones (score: 100)
# ✅ Match: Perry Jones → Perry Jones (score: 100)
# ✅ Match: Terrence Jones → Terrence Jones (score: 100)
# ✅ Match: Kris Joseph → Kris Joseph (score: 100)
# ✅ Match: Michael Kidd-Gilchrist → Michael Kidd-Gilchrist (score: 100)
# ✅ Match: Doron Lamb → Doron Lamb (score: 100)
# ✅ Match: Jeremy Lamb → Jeremy Lamb (score: 100)
# ✅ Match: Meyers Leonard → Meyers Leonard (score: 100)
# ✅ Match: Damian Lillard → Damian Lillard (score: 100)
# ✅ Match: Scott Machado → Scott Machado (score: 100)
# ✅ Match: Kendall Marshall → Kendall Marshall (score: 100)
# ✅ Match: Fab Melo → Fab Melo (score: 100)
# ✅ Match: Khris Middleton → Khris Middleton (score: 100)
# ✅ Match: Darius Miller → Darius Miller (score: 100)
# ✅ Match: Quincy Miller → Quincy Miller (score: 100)
# ✅ Match: Arnett Moultrie → Arnett Moultrie (score: 100)
# ✅ Match: Kevin Murphy → Kevin Murphy (score: 100)
# ✅ Match: Andrew Nicholson → Andrew Nicholson (score: 100)
# ✅ Match: Kyle O'Quinn → Kyle O'Quinn (score: 100)
# ✅ Match: Miles Plumlee → Miles Plumlee (score: 100)
# ✅ Match: Austin Rivers → Austin Rivers (score: 100)
# ✅ Match: Thomas Robinson → Thomas Robinson (score: 100)
# ✅ Match: Terrence Ross → Terrence Ross (score: 100)
# ✅ Match: Tomas Satoransky → TomÃ¡Å¡ SatoranskÃ½ (score: 90)
# ✅ Match: Mike Scott → Mike Scott (score: 100)
# ✅ Match: Henry Sims → Henry Sims (score: 100)
# ✅ Match: Jared Sullinger → Jared Sullinger (score: 100)
# ✅ Match: Jeff Taylor → Jeff Taylor (score: 100)
# ✅ Match: Jordan Taylor → Jermaine Taylor (score: 79)
# ✅ Match: Tyshawn Taylor → Tyshawn Taylor (score: 100)
# ✅ Match: Marquis Teague → Marquis Teague (score: 100)
# ✅ Match: Hollis Thompson → Hollis Thompson (score: 100)
# ✅ Match: Dion Waiters → Dion Waiters (score: 100)
# ✅ Match: Royce White → Royce White (score: 100)
# ✅ Match: Tony Wroten → Tony Wroten (score: 100)
# ✅ Match: Tyler Zeller → Tyler Zeller (score: 100)
# ✅ Match: Keith Benson → Keith Benson (score: 100)
# ✅ Match: Marshon Brooks → MarShon Brooks (score: 100)
# ✅ Match: Alec Burks → Alec Burks (score: 100)
# ✅ Match: Jimmy Butler → Jimmy Butler (score: 100)
# ✅ Match: Norris Cole → Norris Cole (score: 100)
# ❌ No strong match: Jon Diebler → Closest: John Butler (score: 73)
# ❌ No strong match: Michael Dunigan → Closest: Donovan Mitchell (score: 71)
# ❌ No strong match: LaceDarius Dunn → Closest: Kris Dunn (score: 67)
# ✅ Match: Kenneth Faried → Kenneth Faried (score: 100)
# ✅ Match: James Fredette → Jimmer Fredette (score: 83)
# ✅ Match: Andrew Goudelock → Andrew Goudelock (score: 100)
# ✅ Match: Jordan Hamilton → Jordan Hamilton (score: 100)
# ✅ Match: Justin Harper → Justin Harper (score: 100)
# ✅ Match: Tobias Harris → Tobias Harris (score: 100)
# ✅ Match: Tyler Honeycutt → Tyler Honeycutt (score: 100)
# ✅ Match: Scotty Hopson → Scotty Hopson (score: 100)
# ✅ Match: Kyrie Irving → Kyrie Irving (score: 100)
# ✅ Match: Rick Jackson → Marc Jackson (score: 83)
# ✅ Match: Charles Jenkins → Charles Jenkins (score: 100)
# ✅ Match: JaJuan Johnson → JaJuan Johnson (score: 100)
# ✅ Match: Cory Joseph → Cory Joseph (score: 100)
# ❌ No strong match: Enes Kanter → Closest: Kaniel Dickens (score: 64)
# ✅ Match: Brandon Knight → Brandon Knight (score: 100)
# ✅ Match: Malcolm Lee → Malcolm Lee (score: 100)
# ✅ Match: Kawhi Leonard → Kawhi Leonard (score: 100)
# ✅ Match: Travis Leslie → Travis Leslie (score: 100)
# ✅ Match: Jon Leuer → Jon Leuer (score: 100)
# ✅ Match: DeAndre Liggins → DeAndre Liggins (score: 100)
# ❌ No strong match: David Lighty → Closest: David Lee (score: 67)
# ✅ Match: Shelvin Mack → Shelvin Mack (score: 100)
# ❌ No strong match: Demetri McCamey → Closest: Erik McCree (score: 62)
# ✅ Match: E'Twaun Moore → E'Twaun Moore (score: 100)
# ✅ Match: Darius Morris → Darius Morris (score: 100)
# ✅ Match: Marcus Morris → Marcus Morris (score: 100)
# ✅ Match: Markieff Morris → Markieff Morris (score: 100)
# ✅ Match: Chandler Parsons → Chandler Parsons (score: 100)
# ✅ Match: Jereme Richmond → Jeremy Richardson (score: 75)
# ✅ Match: Josh Selby → Josh Selby (score: 100)
# ✅ Match: Iman Shumpert → Iman Shumpert (score: 100)
# ✅ Match: Kyle Singler → Kyle Singler (score: 100)
# ✅ Match: Chris Singleton → Chris Singleton (score: 100)
# ❌ No strong match: Jamie Skeen → Closest: Mike Sweetney (score: 67)
# ✅ Match: Gregory Smith → Greg Smith (score: 87)
# ✅ Match: Nolan Smith → Nolan Smith (score: 100)
# ✅ Match: Isaiah Thomas → Isaiah Thomas (score: 100)
# ✅ Match: Malcolm Thomas → Malcolm Thomas (score: 100)
# ✅ Match: Trey Thompkins → Trey Thompkins (score: 100)
# ✅ Match: Klay Thompson → Klay Thompson (score: 100)
# ✅ Match: Tristan Thompson → Tristan Thompson (score: 100)
# ✅ Match: Jeremy Tyler → Jeremy Tyler (score: 100)
# ✅ Match: Nikola Vucevic → Nikola VuÄeviÄ‡ (score: 92)
# ✅ Match: Kemba Walker → Kemba Walker (score: 100)
# ✅ Match: Derrick Williams → Derrick Williams (score: 100)
# ✅ Match: Jordan Williams → Jordan Williams (score: 100)
# ✅ Match: Solomon Alabi → Solomon Alabi (score: 100)
# ✅ Match: Cole Aldrich → Cole Aldrich (score: 100)
# ✅ Match: Al-Farouq Aminu → Al-Farouq Aminu (score: 100)
# ✅ Match: James Anderson → James Anderson (score: 100)
# ✅ Match: Luke Babbitt → Luke Babbitt (score: 100)
# ✅ Match: Eric Bledsoe → Eric Bledsoe (score: 100)
# ✅ Match: Trevor Booker → Trevor Booker (score: 100)
# ✅ Match: Craig Brackins → Craig Brackins (score: 100)
# ✅ Match: Avery Bradley → Avery Bradley (score: 100)
# ✅ Match: Derrick Caracter → Derrick Caracter (score: 100)
# ✅ Match: Sherron Collins → Sherron Collins (score: 100)
# ✅ Match: DeMarcus Cousins → DeMarcus Cousins (score: 100)
# ✅ Match: Jordan Crawford → Jordan Crawford (score: 100)
# ✅ Match: Ed Davis → Ed Davis (score: 100)
# ✅ Match: Devin Ebanks → Devin Ebanks (score: 100)
# ✅ Match: Derrick Favors → Derrick Favors (score: 100)
# ✅ Match: Keith Gallon → Keith Bogans (score: 75)
# ✅ Match: Charles Garcia → Alex Garcia (score: 80)
# ✅ Match: Paul George → Paul George (score: 100)
# ✅ Match: Luke Harangody → Luke Harangody (score: 100)
# ✅ Match: Manny Harris → Manny Harris (score: 100)
# ✅ Match: Gordon Hayward → Gordon Hayward (score: 100)
# ✅ Match: Lazar Hayward → Lazar Hayward (score: 100)
# ✅ Match: Xavier Henry → Xavier Henry (score: 100)
# ✅ Match: Darington Hobson → Darington Hobson (score: 100)
# ✅ Match: Damion James → Damion James (score: 100)
# ✅ Match: Armon Johnson → Armon Johnson (score: 100)
# ✅ Match: Wesley Johnson → Wesley Johnson (score: 100)
# ✅ Match: Dominique Jones → Dominique Jones (score: 100)
# ✅ Match: Jerome Jordan → Jerome Jordan (score: 100)
# ❌ No strong match: Sylven Landesberg → Closest: Kyle Alexander (score: 65)
# ✅ Match: Gani Lawal → Gani Lawal (score: 100)
# ✅ Match: Greg Monroe → Greg Monroe (score: 100)
# ✅ Match: Daniel Orton → Daniel Orton (score: 100)
# ❌ No strong match: Artsiom Parakhouski → Closest: Marko JariÄ‡ (score: 55)
# ✅ Match: Patrick Patterson → Patrick Patterson (score: 100)
# ✅ Match: Dexter Pittman → Dexter Pittman (score: 100)
# ✅ Match: Andy Rautins → Andy Rautins (score: 100)
# ❌ No strong match: Ryan Richards → Closest: Ryan Reid (score: 73)
# ✅ Match: Stanley Robinson → Stanley Johnson (score: 84)
# ✅ Match: Larry Sanders → Larry Sanders (score: 100)
# ❌ No strong match: Jon Scheyer → Closest: Jon Leuer (score: 70)
# ✅ Match: Lance Stephenson → Lance Stephenson (score: 100)
# ❌ No strong match: Mikhail Torrance → Closest: Terance Mann (score: 64)
# ✅ Match: Evan Turner → Evan Turner (score: 100)
# ✅ Match: Ekpe Udoh → Ekpe Udoh (score: 100)
# ✅ Match: Jarvis Varnado → Jarvis Varnado (score: 100)
# ✅ Match: Greivis Vasquez → Greivis VÃ¡squez (score: 97)
# ✅ Match: John Wall → John Wall (score: 100)
# ✅ Match: Willie Warren → Willie Warren (score: 100)
# ✅ Match: Terrico White → Derrick White (score: 85)
# ✅ Match: Hassan Whiteside → Hassan Whiteside (score: 100)
# ✅ Match: Jeff Adrien → Jeff Adrien (score: 100)
# ✅ Match: Jeff Ayres → Jeff Ayres (score: 100)
# ✅ Match: Rodrigue Beaubois → Rodrigue Beaubois (score: 100)
# ✅ Match: DeJuan Blair → DeJuan Blair (score: 100)
# ✅ Match: Derrick Brown → Derrick Brown (score: 100)
# ✅ Match: Chase Budinger → Chase Budinger (score: 100)
# ✅ Match: DeMarre Carroll → DeMarre Carroll (score: 100)
# ✅ Match: Omri Casspi → Omri Casspi (score: 100)
# ✅ Match: Dionte Christmas → Dionte Christmas (score: 100)
# ✅ Match: Earl Clark → Earl Clark (score: 100)
# ✅ Match: Darren Collison → Darren Collison (score: 100)
# ✅ Match: Dante Cunningham → Dante Cunningham (score: 100)
# ✅ Match: Stephen Curry → Stephen Curry (score: 100)
# ✅ Match: Austin Daye → Austin Daye (score: 100)
# ✅ Match: DeMar DeRozan → DeMar DeRozan (score: 100)
# ✅ Match: Toney Douglas → Toney Douglas (score: 100)
# ✅ Match: Wayne Ellington → Wayne Ellington (score: 100)
# ✅ Match: Tyreke Evans → Tyreke Evans (score: 100)
# ...
# - Billy Preston → Closest: Billy Garrett (score: 69)
# - Austin Wiley → Closest: Willie Cauley-Stein (score: 73)
# - Edrice Adebayo → Closest: Bam Adebayo (score: 64)
# - V.J. Beachem → Closest: MarJon Beauchamp (score: 62)
# - Peter Jok → Closest: Johan Petro (score: 70)
# - Kennedy Meeks → Closest: D.J. Kennedy (score: 61)
# - Melo Trimble → Closest: Allonzo Trier (score: 56)
# - Elgin Cook → Closest: Quinn Cook (score: 70)
# - Isaiah Cousins → Closest: Isaiah Collier (score: 71)
# - Perry Ellis → Closest: Perry Jones (score: 73)
# - Ryan Boatright → Closest: Matt Ryan (score: 70)
# - Olivier Hanlan → Closest: Dean Oliver (score: 72)
# - Corey Hawkins → Closest: Cory Higgins (score: 72)
# - Jonathan Holmes → Closest: Nathan Mensah (score: 71)
# - Terran Petteway → Closest: Terry Taylor (score: 59)
# - Michael Qualls → Closest: Michael Redd (score: 62)
# - J.P. Tokoto → Closest: Elie Okobo (score: 53)
# - Robert Upshaw → Closest: Robert Swift (score: 72)
# - Dez Wells → Closest: Jaylen Wells (score: 67)
# - Jordan Bachynski → Closest: Jordan Hill (score: 67)
# - DeAndre Daniels → Closest: Erik Daniels (score: 74)
# - C.J. Fair → Closest: C.J. Miles (score: 53)
# - Patric Young → Closest: Nick Young (score: 73)
# - Jackie Carmichael → Closest: Michael Redd (score: 62)
# - Will Clyburn → Closest: Will Barton (score: 70)
# - Richard Howell → Closest: Chris Richard (score: 67)
# - Colton Iverson → Closest: Jason Collier (score: 67)
# - Myck Kabongo → Closest: Alfonzo McKinnie (score: 57)
# - CJ Leslie → Closest: C.J. Miles (score: 71)
# - Marcus Denmon → Closest: Marcus Derrickson (score: 73)
# - Tu Holloway → Closest: Jrue Holiday (score: 61)
# - Jon Diebler → Closest: John Butler (score: 73)
# - Michael Dunigan → Closest: Donovan Mitchell (score: 71)
# - LaceDarius Dunn → Closest: Kris Dunn (score: 67)
# - Enes Kanter → Closest: Kaniel Dickens (score: 64)
# - David Lighty → Closest: David Lee (score: 67)
# - Demetri McCamey → Closest: Erik McCree (score: 62)
# - Jamie Skeen → Closest: Mike Sweetney (score: 67)
# - Sylven Landesberg → Closest: Kyle Alexander (score: 65)
# - Artsiom Parakhouski → Closest: Marko JariÄ‡ (score: 55)
# - Ryan Richards → Closest: Ryan Reid (score: 73)
# - Jon Scheyer → Closest: Jon Leuer (score: 70)
# - Mikhail Torrance → Closest: Terance Mann (score: 64)
# - Josh Heytvelt → Closest: Josh Huestis (score: 64)
# - Jack McClinton → Closest: Dan McClintock (score: 71)
# - Tyrone Brazelton → Closest: Jaylon Tyson (score: 64)
# - Keith Brumbaugh → Closest: Keith Bogans (score: 59)
# - Stanley Burrell → Closest: Cassius Stanley (score: 60)
# - Brian Butch → Closest: Brian Cook (score: 67)
# - Pat Calathes → Closest: Nick Calathes (score: 72)
# - Chris Daniels → Closest: Chris Duarte (score: 72)
# - Marcus Dove → Closest: Marcus Fizer (score: 70)
# - Josh Duncan → Closest: DeQuan Jones (score: 70)
# - Frank Elegar → Closest: Ian Clark (score: 57)
# - Shan Foster → Closest: Michael Foster Jr. (score: 72)
# - Vladimir Golubovic → Closest: Vladimir RadmanoviÄ‡ (score: 67)
# - Kentrell Gransberry → Closest: Tyrell Terry (score: 65)
# - Kyle Hines → Closest: Kyle Anderson (score: 70)
# - Jiri Hubalek → Closest: Alex Kirk (score: 57)
# - Marcelus Kemp → Closest: Marcus Fizer (score: 64)
# - Maarty Leunen → Closest: Kenyon Martin (score: 62)
# - Longar Longar → Closest: Art Long (score: 67)
# - Aleks Maric → Closest: Maurice Harkless (score: 74)
# - Drew Neitzel → Closest: Andrew White (score: 67)
# - David Padgett → Closest: David West (score: 70)
# - Trent Plaisted → Closest: Terence Davis (score: 59)
# - Quan Prowell → Closest: Zabian Dowdell (score: 62)
# - Shaun Pruitt → Closest: Tayshaun Prince (score: 67)
# - Charles Rhodes → Closest: Charles Cooke (score: 74)
# - Russell Robinson → Closest: Thomas Robinson (score: 65)
# - Richard Roby → Closest: Robert Archibald (score: 64)
# - Ronald Steele → Closest: Donald Sloan (score: 64)
# - Bryce Taylor → Closest: Mike Taylor (score: 70)
# - Mark Tyndale → Closest: Jock Landale (score: 58)
# - Mohamed Abukar → Closest: Mouhamed Gueye (score: 64)
# - Mario Boggan → Closest: Mario Kasun (score: 70)
# - Craig Bradshaw → Closest: Craig Brackins (score: 71)
# - Russell Carter → Closest: Wendell Carter Jr. (score: 71)
# - Coleman Collins → Closest: Colin Castleton (score: 67)
# - Ryvon Covile → Closest: Trayvon Palmer (score: 62)
# - Justin Doellman → Closest: Justin Dentmon (score: 69)
# - Rashaun Freeman → Closest: Kareem Rush (score: 62)
# - Caleb Green → Closest: A.J. Green (score: 74)
# - Brandon Heath → Closest: Brandon Hunter (score: 74)
# - Herbert Hill → Closest: George Hill (score: 70)
# - Quinton Hosley → Closest: Quinten Post (score: 69)
# - James Hughes → Closest: James Ennis III (score: 70)
# - Jeremy Hunt → Closest: Jeremy Evans (score: 70)
# - Ekene Ibekwe → Closest: Orien Greene (score: 58)
# - Rashad Jones-Jennings → Closest: Brandon Jennings (score: 56)
# - Antanas Kavaliauskas → Closest: Arvydas Macijauskas (score: 62)
# - Marko Lekic → Closest: Marko JariÄ‡ (score: 67)
# - Ron Lewis → Closest: Jalen Wilson (score: 67)
# - Sammy Mejia → Closest: Salah Mejri (score: 64)
# - Ivan Radenovic → Closest: Boban MarjanoviÄ‡ (score: 62)
# - JR Reynolds → Closest: Cameron Reynolds (score: 67)
# - Dustin Salisbery → Closest: Austin Rivers (score: 62)
# - Blake Schilb → Closest: Blake Wesley (score: 67)
# - Renaldas Seibutis → Closest: Å arÅ«nas JasikeviÄius (score: 59)
# - Curtis Sumpter → Closest: Chris Porter (score: 69)
# - Jamaal Tatum → Closest: Jayson Tatum (score: 67)
# - Reyshawn Terry → Closest: Emanuel Terry (score: 67)
# - Kyle Visser → Closest: Kyle Weaver (score: 73)
# - Major Wingate → Closest: Nate Darling (score: 64)
# - DaShaun Wood → Closest: Brendan Haywood (score: 59)
# - Avis Wyatt → Closest: Travis Wear (score: 67)
# - Kenny Adeleke → Closest: Kennedy Chandler (score: 69)
# - J.P. Batista → Closest: Mike Batiste (score: 64)
# - Brad Buckman → Closest: Branden Carlson (score: 59)
# - Nik Caner-Medley → Closest: Mike Conley (score: 62)
# - Keydren Clark → Closest: Jaylen Clark (score: 72)
# - Taquan Dean → Closest: Taurean Green (score: 67)
# - Sean Dockery → Closest: Sam Dekker (score: 64)
# - Torin Francis → Closest: Francisco GarcÃ­a (score: 64)
# - Taj Gray → Closest: Josh Gray (score: 71)
# - Dan Grunfeld → Closest: Danny Granger (score: 64)
# - Matt Haryasz → Closest: Matt Barnes (score: 70)
# - Eric Hicks → Closest: Eric Mika (score: 74)
# - Tedric Hill → Closest: Tyler Hall (score: 67)
# - Viktor Keyru → Closest: Viktor Khryapa (score: 69)
# - Marco Killingsworth → Closest: Kyle Collinsworth (score: 61)
# - Carl Krauser → Closest: Armel TraorÃ© (score: 61)
# - Gerry McNamara → Closest: Jerel McNeal (score: 54)
# - Yemi Nicholson → Closest: Sean Colson (score: 64)
# - Danilo Pinnock → Closest: Dan McClintock (score: 64)
# - Michael Southhall → Closest: Michael Porter Jr. (score: 65)
# - Frans Steyn → Closest: Ansu Sesay (score: 67)
# - Curtis Stinson → Closest: Chris Singleton (score: 69)
# - Ian Vouyoukas → Closest: Brian Cook (score: 61)
# - Curtis Withers → Closest: Chris Owens (score: 64)
# - Deji Akindele → Closest: Deng Adel (score: 64)
# - Nemanja Aleksandrov → Closest: Nemanja NedoviÄ‡ (score: 73)
# - Sean Banks → Closest: Ansu Sesay (score: 70)
# - Marcus Campbell → Closest: Marcus Bagley (score: 64)
# - Taylor Coppenrath → Closest: Taylor Hendricks (score: 61)
# - Daryl Dorsey → Closest: Carl Landry (score: 61)
# - D'Or Fischer → Closest: Corey Kispert (score: 58)
# - Eddy Fobbs → Closest: Eddie House (score: 57)
# - John Gilchrist → Closest: Chris Johnson (score: 74)
# - Charles Hayes → Closest: Charles Jenkins (score: 71)
# - Jared Homan → Closest: Jared Harper (score: 70)
# - Mindaugas Katelynas → Closest: Mindaugas Kuzminskas (score: 72)
# - Jason Klotz → Closest: Jason Kapono (score: 70)
# - David Lucas → Closest: Kalin Lucas (score: 73)
# - Juan Mendez → Closest: Dewan Hernandez (score: 62)
# - Ellis Myles → Closest: Keon Ellis (score: 67)
# - Larry O'Bannon → Closest: Larry Owens (score: 67)
# - Drago Pasalic → Closest: Predrag SavoviÄ‡ (score: 59)
# - Kevin Pittsnogle → Closest: Kevinn Pinkney (score: 67)
# - Tre Simmons → Closest: Tre Jones (score: 70)
# - Brian Boddicker → Closest: Brian Bowen (score: 69)
# - Tim Bowers → Closest: Tariq Owens (score: 67)
# - Aleksandar Capin → Closest: Cliff Alexander (score: 65)
# - Ales Chan → Closest: Richaun Holmes (score: 70)
# - TJ Cummings → Closest: Joe Ingles (score: 57)
# - Marcus Douthit → Closest: Marcus Cousin (score: 74)
# - Chris Garnett → Closest: Chris Duarte (score: 72)
# - Rolando Howell → Closest: Ron Holland (score: 64)
# - Ivan Koljevic → Closest: Tristan Vukcevic (score: 62)
# - Herve Lamizana → Closest: Kevin Hervey (score: 62)
# - Sergei Lishouk → Closest: Serge Ibaka (score: 64)
# - Jaime Lloreda → Closest: Jerome Jordan (score: 62)
# - Bryant Matthews → Closest: Matthew Hurt (score: 74)
# - Marcus Melvin → Closest: Shelvin Mack (score: 72)
# - Rich Melzer → Closest: Quincy Miller (score: 58)
# - Ricky Minard → Closest: Ricky Ledo (score: 64)
# - Michel Morandais → Closest: Michael Redd (score: 64)
# - Misan Nikagbatse → Closest: Nate Huffman (score: 57)
# - Randall Orr → Closest: Randolph Morris (score: 69)
# - Dylan Page → Closest: Jaysean Paige (score: 70)
# - Rickey Paulding → Closest: Ricky Ledo (score: 64)
# - Kelvin Pena → Closest: Kevin Porter Jr. (score: 70)
# - Tim Pickett → Closest: Jalen Pickett (score: 58)
# - Omar Quintero → Closest: Quinten Post (score: 64)
# - Aerick Sanders → Closest: Larry Sanders (score: 74)
# - Romain Sato → Closest: Yao Ming (score: 63)
# - Blagota Sekulic → Closest: Sekou Doumbouya (score: 53)
# - Tom Timmerrmans → Closest: TomÃ¡Å¡ SatoranskÃ½ (score: 64)
# - Marko Tomas → Closest: Matt Thomas (score: 73)
# - Rashad Wright → Closest: Brandan Wright (score: 74)
# - Aloysius Anagonye → Closest: Darius Washington (score: 59)
# - LaVell Blanchard → Closest: Ahmad Caver (score: 59)
# - Jermaine Boyette → Closest: Jamaree Bouyea (score: 60)
# - Joel Cornette → Closest: Joseph Forte (score: 64)
# - Aleksander Djuric → Closest: Joe Alexander (score: 67)
# - Ruben Douglas → Closest: RubÃ©n GarcÃ©s (score: 70)
# - Carl English → Closest: Charles Jenkins (score: 67)
# - Ebi Ere → Closest: DeAndre' Bembry (score: 57)
# - Marquis Estill → Closest: Marquis Daniels (score: 69)
# - Jason Gardner → Closest: Thomas Gardner (score: 74)
# - Trevor Harvey → Closest: Trevor Ariza (score: 72)
# - Marcus Hatten → Closest: Marcus Garrett (score: 74)
# - Jerry Holman → Closest: Emanuel Terry (score: 64)
# - Sam Hoskin → Closest: Sam Hauser (score: 60)
# - Sani Ibrahim → Closest: Malaki Branham (score: 62)
# - Michael Ignerski → Closest: Michael Gbinije (score: 71)
# - Jason Keep → Closest: Jason Kapono (score: 73)
# - Bernard King → Closest: Bernard Robinson (score: 71)
# - Donald Little → Closest: Donald Sloan (score: 64)
# - Chris Massie → Closest: Marquese Chriss (score: 74)
# - Will McDonald → Closest: Will Conroy (score: 67)
# - Jeff Newton → Closest: Jeff Taylor (score: 64)
# - Uche Nsonwu-Amadi → Closest: Cason Wallace (score: 55)
# - Ugonna Okyekwe → Closest: Kyle O'Quinn (score: 56)
# - Marlon Parmer → Closest: Desmon Farmer (score: 69)
# - Stephane Pelle → Closest: StÃ©phane Lasme (score: 74)
# - Hollis Price → Closest: Ryan Hollins (score: 67)
# - Joe Shipp → Closest: Joe Wieskamp (score: 57)
# - Ron Slay → Closest: Aaron Gray (score: 67)
# - Marvin Stone → Closest: Alvin Jones (score: 70)
# - Wayne Wallace → Closest: Allan Ray (score: 64)
# - Wesley Wilson → Closest: Jalen Wilson (score: 72)
# - Doug Wrenn → Closest: DontÃ© Greene (score: 57)
# - Lubos Barton → Closest: Will Barton (score: 70)
# - Lee Benson → Closest: Keith Benson (score: 73)
# - Brian Brown → Closest: Andre Brown (score: 73)
# - Sylvere Bryan → Closest: Tyler Bey (score: 64)
# - Chris Burgess → Closest: Chris Bosh (score: 70)
# - Mire Chatman → Closest: Kirk Haston (score: 61)
# - Chris Christoffersen → Closest: Chris Jefferies (score: 63)
# - Lenny Cooke → Closest: Quinn Cook (score: 67)
# - Craig Dawson → Closest: Branden Dawson (score: 69)
# - Teddy Dupay → Closest: Eddy Curry (score: 67)
# - Andy Ellis → Closest: Jay Williams (score: 64)
# - Peter Fehse → Closest: Alec Peters (score: 64)
# - David Graves → Closest: David West (score: 73)
# - Rod Grizzard → Closest: Jared Rhoden (score: 58)
# - Damon Hancock → Closest: Armon Johnson (score: 62)
# - Lonnie Jones → Closest: Solomon Jones (score: 72)
# - Sean Kennedy → Closest: D.J. Kennedy (score: 64)
# - Kris Lang → Closest: Karim ManÃ© (score: 67)
# - Muhammed Lasege → Closest: Mouhamed Gueye (score: 69)
# - Steve Logan → Closest: Steve Blake (score: 73)
# - Kei Madison → Closest: Kevin Martin (score: 70)
# - Immanuel McElroy → Closest: Immanuel Quickley (score: 73)
# - Aaron McGhee → Closest: Aaron Miles (score: 70)
# - Elvin Mims → Closest: Devin Harris (score: 64)
# - Byron Mouton → Closest: Byron Mullens (score: 72)
# - Uche Okafor → Closest: Okaro White (score: 64)
# - Luke Recker → Closest: Luke Zeller (score: 73)
# - Rolan Roberts → Closest: Robert Sacre (score: 64)
# - Brooks Sales → Closest: Brook Lopez (score: 70)
# - Julian Sensley → Closest: Julyan Stone (score: 62)
# - Israel Sheinfeld → Closest: Admiral Schofield (score: 67)
# - Preston Shumpert → Closest: Iman Shumpert (score: 69)
# - Marcus Taylor → Closest: Marcus Thornton (score: 71)
# - Adam Allenspach → Closest: Jaylen Adams (score: 67)
# - Cookie Belcher → Closest: Jackie Butler (score: 67)
# - Calvin Bowman → Closest: Charlie Brown Jr. (score: 69)
# - SirValiant Brown → Closest: Sterling Brown (score: 73)
# - Eric Chenowith → Closest: Eric Bledsoe (score: 54)
# - Sam Clancy → Closest: Landry Shamet (score: 70)
# - Gyasi Cline-Heard → Closest: Cezary TrybaÅ„ski (score: 58)
# - Tate Decker → Closest: Alex Acker (score: 67)
# - Robb Dryden → Closest: Rob Edwards (score: 64)
# - Benjamin Eze → Closest: Damion Lee (score: 64)
# - Kimani Ffriend → Closest: Kaniel Dickens (score: 57)
# - Kenny Gregory → Closest: Greg Oden (score: 64)
# - Charles Hathaway → Closest: Charles Cooke (score: 55)
# - Michael Hicks → Closest: Michael Foster Jr. (score: 67)
# - Andre Hutson → Closest: Andrew Harrison (score: 74)
# - Darren Kelly → Closest: Willie Warren (score: 64)
# - Zach Marbury → Closest: Larry Nance Jr. (score: 61)
# - Mike Mardesich → Closest: Mike James (score: 67)
# - Troy Ostler → Closest: Trey Gilder (score: 64)
# - Lazaros Papadopoulos → Closest: Paolo Banchero (score: 53)
# - Rashad Phillips → Closest: Phillip Wheeler (score: 60)
# - Demetrius Porter → Closest: Chris Porter (score: 71)
# - Martin Rancik → Closest: Terance Mann (score: 64)
# - Lee Scruggs → Closest: Jalen Suggs (score: 73)
# - Greg Stevenson → Closest: DeShawn Stevenson (score: 71)
# - Souleymane Wane → Closest: Wayne Selden (score: 67)
# - Michael Wright → Closest: Michael Porter Jr. (score: 71)
# - Harold Arceneaux → Closest: Brendan Haywood (score: 58)
# - Mario Bland → Closest: Mario Kasun (score: 73)
# - Eric Coley → Closest: Erick Barkley (score: 70)
# - Ed Cota → Closest: Tre Scott (score: 62)
# - Schea Cotton → Closest: Sean Colson (score: 70)
# - Caswell Cyrus → Closest: Tyrus Thomas (score: 56)
# - Julius Doc Robinson → Closest: Justin Robinson (score: 71)
# - Vassil Evtimov → Closest: Devin Vassell (score: 67)
# - Ceedric Goodwyn → Closest: Eric Gordon (score: 69)
# - Johnny Hemsley → Closest: Johnny Furphy (score: 67)
# - Michael Hermon → Closest: Michael Foster Jr. (score: 71)
# - Cory Hightower → Closest: Coby White (score: 67)
# - Shaheen Holloway → Closest: Steven Hill (score: 59)
# - Jimmie Hunter → Closest: R.J. Hunter (score: 73)
# - Jacob Jaacks → Closest: Jacob Evans (score: 70)
# - Mark Karcher → Closest: Marko JariÄ‡ (score: 64)
# - Justin Love → Closest: Justin Reed (score: 73)
# - Pete Mickeal → Closest: MickaÃ«l PiÃ©trus (score: 72)
# - Brian Montonati → Closest: Brian Cook (score: 64)
# - Gabe Muoneke → Closest: Gal Mekel (score: 67)
# - Ndongo N'diaye → Closest: Boniface N'Dong (score: 74)
# - Matthew Nielsen → Closest: Wesley Matthews (score: 73)
# - Reed Rawlings → Closest: Reece Gaines (score: 64)
# - Aubrey Reese → Closest: Alex Reese (score: 73)
# - Matt Santangelo → Closest: Yante Maten (score: 62)
# - Karim Shabazz → Closest: Shabazz Napier (score: 74)
# - Jarrett Stephens → Closest: D.J. Stephens (score: 74)
# - Bootsy Thornton → Closest: Al Thornton (score: 69)
# - Jaquay Walls → Closest: Jay Williams (score: 67)
# - Jameel Watkins → Closest: Jameel Warney (score: 74)

# %%
midrange_matches = {
    player: (matched_name, score)
    for player, (matched_name, score) in closest_match_dict.items()
    if 75 <= score < 100 and matched_name != "No match found"
}

print("\n Matches with scores between 75 and 99:")
for player, (matched_name, score) in midrange_matches.items():
    print(f"- {player} → {matched_name} (score: {score})")

midrange_df = pd.DataFrame([
    {"Combine_Player": player, "Matched_Rookie_Player": matched_name, "Score": score}
    for player, (matched_name, score) in midrange_matches.items()
])

midrange_df.to_csv("midrange_matches_75_99.csv", index=False)
print("Saved midrange matches to midrange_matches_75_99.csv")
# Out:
# 🟡 Matches with scores between 75 and 99:
# - Michael Ajayi → Ajay Mitchell (score: 85)
# - Robert Dillingham → Rob Dillingham (score: 90)
# - David Jones → David Johnson (score: 83)
# - Jaxson Robinson → Justin Robinson (score: 80)
# - Tidjane Salaun → Tidjane SalaÃ¼n (score: 96)
# - Alexandre Sarr → Alex Sarr (score: 78)
# - JT Toppin → Jacob Toppin (score: 76)
# - Mike Miles Jr. → Mike Miller (score: 86)
# - Dillon Mitchell → Davion Mitchell (score: 87)
# - Moussa Diabate → Moussa DiabatÃ© (score: 96)
# - Nikola Jovic → Nikola JoviÄ‡ (score: 96)
# - Trevion Williams → Marvin Williams (score: 84)
# - Matt Hurt → Matthew Hurt (score: 86)
# - Makur Maker → Maurice Baker (score: 75)
# - John Petty Jr. → Johan Petro (score: 76)
# - Joshua Hall → Josh Hall (score: 90)
# - Theo Maledon → ThÃ©o Maledon (score: 96)
# - Karim Mane → Karim ManÃ© (score: 95)
# - Jayden Scrubb → Jay Scrubb (score: 87)
# - Nicolas Claxton → Nic Claxton (score: 85)
# - Jaylen Hands → Jaylen Adams (score: 83)
# - Jalen Hoard → Jaylen Hoard (score: 96)
# - Cameron Reddish → Cam Reddish (score: 85)
# - Mohamed Bamba → Mo Bamba (score: 76)
# - Jaylen Barford → Jaylen Brown (score: 77)
# - Tony Carr → Tony Parker (score: 80)
# - Brandon McCoy → Brandon Roy (score: 83)
# - Sviatoslav Mykhailiuk → Svi Mykhailiuk (score: 80)
# - Wesley Iwundu → Wes Iwundu (score: 87)
# - Justin Jackson (UMD) → Justin Jackson (score: 88)
# - Justin Jackson (UNC) → Justin Jackson (score: 88)
# - Skal Labissiere → Skal LabissiÃ¨re (score: 97)
# - Marcus Lee → Marcus Bagley (score: 78)
# - Brandon Ashley → Brandon Bass (score: 77)
# - Tyler Harvey → Tyler Bey (score: 76)
# - Chris Walker → Henry Walker (score: 75)
# - Alec Brown → Andre Brown (score: 76)
# - Aaron Craft → Aaron Gray (score: 76)
# - Melvin Ejim → Melvin Ely (score: 76)
# - James McAdoo → James Michael McAdoo (score: 75)
# - LaQuinton Ross → Quinton Ross (score: 92)
# - Xavier Thames → Xavier Rathan-Mayes (score: 84)
# - Kendall Williams → Elliot Williams (score: 77)
# - Kenny Kadji → D.J. Kennedy (score: 76)
# - Trevor Mbakwe → Trevor Booker (score: 77)
# - Dennis Schroder → Dennis SchrÃ¶der (score: 97)
# - Deshaun Thomas → Etan Thomas (score: 80)
# - BJ Young → Joe Young (score: 82)
# - J'Covan Brown → Jaylen Brown (score: 75)
# - William Buford → William Howard (score: 79)
# - Tomas Satoransky → TomÃ¡Å¡ SatoranskÃ½ (score: 90)
# - Jordan Taylor → Jermaine Taylor (score: 79)
# - James Fredette → Jimmer Fredette (score: 83)
# - Rick Jackson → Marc Jackson (score: 83)
# - Jereme Richmond → Jeremy Richardson (score: 75)
# - Gregory Smith → Greg Smith (score: 87)
# - Nikola Vucevic → Nikola VuÄeviÄ‡ (score: 92)
# - Keith Gallon → Keith Bogans (score: 75)
# - Charles Garcia → Alex Garcia (score: 80)
# - Stanley Robinson → Stanley Johnson (score: 84)
# - Greivis Vasquez → Greivis VÃ¡squez (score: 97)
# - Terrico White → Derrick White (score: 85)
# - Ramel Bradley → Michael Bradley (score: 79)
# - Takais Brown → Jabari Brown (score: 75)
# - Jamar Butler → Jared Butler (score: 83)
# - James Gist → James Ennis III (score: 76)
# - Donte Greene → DontÃ© Greene (score: 96)
# - DeVon Hardin → Devin Harris (score: 75)
# - Richard Hendrix → Chris Richard (score: 79)
# - Shawn James → James Lang (score: 76)
# - Davon Jefferson → Al Jefferson (score: 81)
# - Joseph Jones → Joseph Forte (score: 75)
# - James Mays → James Thomas (score: 82)
# - Robert Vaden → Robert Sacre (score: 75)
# - Deron Washington → Duane Washington Jr. (score: 81)
# - Dominic James → Damion James (score: 80)
# - Jared Jordan → Jerome Jordan (score: 80)
# - Stephane Lasme → StÃ©phane Lasme (score: 96)
# - Brad Newley → Ira Newble (score: 76)
# - Ali Traore → Armel TraorÃ© (score: 76)
# - Rashad Anderson → Ryan Anderson (score: 79)
# - Brandon Bowman → Brandon Boston Jr. (score: 79)
# - Denham Brown → Devin Brown (score: 78)
# - Terence Dials → Terence Davis (score: 85)
# - Nick George → Georges Niang (score: 75)
# - Daniel Horton → Daniel Orton (score: 96)
# - Paul Miller → Paul Millsap (score: 78)
# - Dwayne Mitchell → Davion Mitchell (score: 80)
# - Antywane Robinson → Nate Robinson (score: 80)
# - Marcus Slaughter → Marcus Sasser (score: 76)
# - Joah Tucker → P.J. Tucker (score: 80)
# - Eric Williams → Derrick Williams (score: 90)
# - Martynas Andriuskevicius → Martynas AndriuÅ¡keviÄius (score: 96)
# - Mike Bell → Mike Hall (score: 78)
# - Rudy Fernandez → Rudy FernÃ¡ndez (score: 96)
# - Francisco Garcia → Francisco GarcÃ­a (score: 97)
# - Ersan Ilyasova → Ersan Ä°lyasova (score: 96)
# - Carlos Powell → Josh Powell (score: 75)
# - David Simon → David Johnson (score: 75)
# - Chris Thomas → Khyri Thomas (score: 83)
# - Omar Thomas → Matt Thomas (score: 82)
# - Martin Iti → Cartier Martin (score: 75)
# - Arthur Johnson → Amir Johnson (score: 77)
# - James Moore → Mike James (score: 76)
# - Marcus Moore → Marcus Morris (score: 80)
# - Peter Ramos → Peter John Ramos (score: 81)
# - Mike Williams → Malik Williams (score: 89)
# - Nate Williams → Matt Williams (score: 85)
# - Rick Anderson → Ryan Anderson (score: 77)
# - Souleymane Camara → Toumani Camara (score: 77)
# - Robert Jackson → Jackson Rowe (score: 85)
# - Chris Marcus → Marquese Chriss (score: 81)
# - Darko Milicic → Darko MiliÄiÄ‡ (score: 92)
# - Tommy Smith → Tolu Smith (score: 76)
# - Michael Sweetney → Mike Sweetney (score: 83)
# - Sasha Vujacic → Sasha VujaÄiÄ‡ (score: 92)
# - Greg Harrington → Greg Whittington (score: 77)
# - Cordell Henry → Henri Drell (score: 75)
# - Jason Jennings → Brandon Jennings (score: 80)
# - Kevin Lyde → Kevin Love (score: 80)
# - Nene → NenÃª (score: 86)
# - Travis Robinson → Thomas Robinson (score: 80)
# - Predrag Savovic → Predrag SavoviÄ‡ (score: 97)
# - Jobey Thomas → Billy Thomas (score: 75)
# - George Williams → Reggie Williams (score: 80)
# - Ryan Carroll → Matt Carroll (score: 75)
# - Anthony Evans → Anthony Edwards (score: 79)
# - Jerry Green → Jeff Green (score: 76)
# - Nate James → James Jones (score: 76)
# - Darrell Johns → Carldell Johnson (score: 76)
# - DeMarcus Minor → DeMarcus Nelson (score: 76)
# - Norman Richardson → Norm Richardson (score: 94)
# - Damone Thornton → Al Thornton (score: 77)
# - Tory Walker → Henry Walker (score: 78)
# - Brent Wright → Bracey Wright (score: 80)
# - Lamont Barnes → Matt Barnes (score: 75)
# - Primoz Brezec → PrimoÅ¾ Brezec (score: 96)
# - Marcus Goree → Marcus Garrett (score: 77)
# - A.J. Granger → Danny Granger (score: 78)
# - Ron Hale → Ron Harper Jr. (score: 78)
# - Marko Jaric → Marko JariÄ‡ (score: 95)
# - Nate Johnson → Trey Johnson (score: 83)
# - Kenyon Jones → Kevin Jones (score: 78)
# - Brandon Kurtz → Brandon Roy (score: 75)
# - Eduardo Najera → Eduardo NÃ¡jera (score: 96)
# - Igor Rakocevic → Igor RakoÄeviÄ‡ (score: 92)
# - Damon Reed → Davon Reed (score: 90)
# - Pepe Sanchez → Pepe SÃ¡nchez (score: 96)
# - Nick Sheppard → Ben Sheppard (score: 80)
# 📁 Saved midrange matches to midrange_matches_75_99.csv

# %% [markdown]
# At this point, some manual work had to be done to only include the incorrec matches in the dataset. Further, a few unmatched players like Carlton Carrington had matches that fuzzymatching did not find (he goes by Bub Carrington)

# %%
merged = pd.read_csv("rookie_stats_with_combine_fuzzy.csv")

incorrect_matches = pd.read_csv("midrange_matches_75_99.csv")

cleaned = merged[~merged["PLAYER"].isin(incorrect_matches["Combine_Player"])].copy()

cleaned.to_csv("rookie_stats_with_combine_cleaned.csv", index=False)
print("Saved cleaned file to rookie_stats_with_combine_cleaned.csv (incorrect matches removed)")
# Out:
# ✅ Saved cleaned file to rookie_stats_with_combine_cleaned.csv (incorrect matches removed)

# %%
df = pd.read_csv("rookie_stats_with_combine_cleaned.csv")

df = df[df["PLAYER"].notna()].copy()

columns_to_drop = ["Team", "Pos", "Awards", "Player_norm", "PLAYER_norm", "PLAYER"]
df.drop(columns=columns_to_drop, inplace=True, errors="ignore")

df.to_csv("rookie_stats_final_clean.csv", index=False)
print("Final cleaned dataset saved to rookie_stats_final_clean.csv")
# Out:
# ✅ Final cleaned dataset saved to rookie_stats_final_clean.csv
